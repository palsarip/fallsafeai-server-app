# %% [markdown]
# ## 4. Feature Engineering
#
# ### `04_feature_engineering.ipynb`

# %%
# Import necessary libraries
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from ultralytics import YOLO
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
# %matplotlib inline

# Set paths
FALL_DATA_DIR = "../data/le2i"
WORKOUT_VIDEOS_DIR = "../data/workout_videos"
OUTPUT_DIR = "../outputs/features"
os.makedirs(OUTPUT_DIR, exist_ok=True)

print(f"Checking data directories:")
print(f"FALL_DATA_DIR exists: {os.path.exists(FALL_DATA_DIR)}")
print(f"WORKOUT_VIDEOS_DIR exists: {os.path.exists(WORKOUT_VIDEOS_DIR)}")
print(f"OUTPUT_DIR exists: {os.path.exists(OUTPUT_DIR)}")

# Initialize YOLO11 models
print("Loading YOLO11 models...")
try:
    yolo_model = YOLO11('yolo11n.pt')  # For person detection
    yolo_pose_model = YOLO11('yolo11n-pose.pt')  # For pose estimation
    print("Models loaded successfully")
except Exception as e:
    print(f"Error loading models: {e}")
    print("Make sure YOLO11 is installed: pip install yolo11")

# Function to extract features from a video
def extract_features_from_video(video_path, num_frames=16):
    """Extract pose and motion features from a video using YOLO11"""
    try:
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            print(f"Error: Could not open video {video_path}")
            return None, None
            
        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        
        print(f"Video info: {frame_width}x{frame_height}, {frame_count} frames")
        
        # Calculate frame indices to sample
        indices = np.linspace(0, frame_count-1, num_frames, dtype=int)
        
        # Keypoint sequences
        keypoint_sequence = []
        is_pose_detected = []
        person_detected = []
        
        for idx in indices:
            cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
            ret, frame = cap.read()
            
            if not ret:
                # If frame reading fails, add placeholder
                keypoint_sequence.append(None)
                is_pose_detected.append(False)
                person_detected.append(False)
                continue
            
            # Person detection with YOLO11
            person_results = yolo_model(frame, classes=[0], conf=0.5)
            
            person_found = False
            
            if len(person_results[0].boxes) > 0:
                person_found = True
                person_detected.append(True)
            else:
                person_detected.append(False)
            
            # Pose detection with YOLO11 pose
            pose_results = yolo_pose_model(frame)
            
            if len(pose_results[0].keypoints.data) > 0:
                is_pose_detected.append(True)
                
                # Get the pose with highest confidence (usually the largest one)
                best_pose_idx = 0
                if len(pose_results[0].boxes) > 1:
                    # If multiple poses, get the one with highest confidence
                    confidences = [box.conf.item() for box in pose_results[0].boxes]
                    best_pose_idx = np.argmax(confidences)
                
                # Extract keypoints for the best pose
                pose_keypoints = pose_results[0].keypoints.data[best_pose_idx]
                
                # Convert to a flat list format
                frame_keypoints = []
                for kp_idx in range(pose_keypoints.shape[0]):
                    x, y, conf = pose_keypoints[kp_idx].tolist()
                    # Normalize coordinates
                    frame_keypoints.extend([
                        float(x) / frame_width,
                        float(y) / frame_height,
                        0.0,  # YOLO11 doesn't provide z-coordinate
                        float(conf)
                    ])
                
                keypoint_sequence.append(frame_keypoints)
            else:
                is_pose_detected.append(False)
                keypoint_sequence.append(None)
        
        cap.release()
        
        # Statistics
        pose_detection_rate = sum(is_pose_detected) / len(is_pose_detected) if is_pose_detected else 0
        person_detection_rate = sum(person_detected) / len(person_detected) if person_detected else 0
        
        print(f"Video: {os.path.basename(video_path)}")
        print(f"Person detection rate: {person_detection_rate:.2f}")
        print(f"Pose detection rate: {pose_detection_rate:.2f}")
        
        # If no poses detected, return None
        if not any(is_pose_detected):
            print("No poses detected in this video")
            return None, None
        
        # Calculate pose-based features
        valid_keypoints = [kp for kp in keypoint_sequence if kp is not None]
        
        if not valid_keypoints:
            print("No valid keypoints found")
            return None, None
        
        # Create features
        features = {}
        
        # 1. Keypoint velocities
        if len(valid_keypoints) >= 2:
            velocities = []
            for i in range(1, len(valid_keypoints)):
                frame_velocities = []
                for j in range(0, len(valid_keypoints[i]), 4):  # Each keypoint has 4 values (x,y,z,v)
                    if j+3 < len(valid_keypoints[i]) and j+3 < len(valid_keypoints[i-1]):
                        # Calculate Euclidean distance between consecutive frames
                        dx = valid_keypoints[i][j] - valid_keypoints[i-1][j]
                        dy = valid_keypoints[i][j+1] - valid_keypoints[i-1][j+1]
                        # Note: YOLO11 doesn't have z-coordinate, so we use 0
                        velocity = np.sqrt(dx**2 + dy**2)
                        frame_velocities.append(velocity)
                
                if frame_velocities:
                    velocities.append(frame_velocities)
            
            if velocities:
                features['max_velocity'] = np.max([np.max(v) if v else 0 for v in velocities])
                features['mean_velocity'] = np.mean([np.mean(v) if v else 0 for v in velocities])
                features['std_velocity'] = np.std([np.std(v) if v else 0 for v in velocities]) if len(velocities) > 1 else 0
        
        # 2. Pose height variation
        heights = []
        for kp in valid_keypoints:
            y_values = [kp[i+1] for i in range(0, len(kp), 4)]
            if y_values:
                height = max(y_values) - min(y_values)
                heights.append(height)
        
        if heights:
            features['max_height'] = np.max(heights)
            features['min_height'] = np.min(heights)
            features['height_range'] = np.max(heights) - np.min(heights)
        
        # 3. Pose width variation
        widths = []
        for kp in valid_keypoints:
            x_values = [kp[i] for i in range(0, len(kp), 4)]
            if x_values:
                width = max(x_values) - min(x_values)
                widths.append(width)
        
        if widths:
            features['max_width'] = np.max(widths)
            features['min_width'] = np.min(widths)
            features['width_range'] = np.max(widths) - np.min(widths)
        
        # 4. Vertical position change (for falls)
        # Note: In YOLO11 pose, nose is keypoint index 0
        nose_positions = []
        for kp in valid_keypoints:
            if len(kp) >= 4:  # Nose is first landmark
                nose_positions.append(kp[1])  # y-coordinate of nose
        
        if nose_positions and len(nose_positions) >= 2:
            features['head_y_change'] = nose_positions[-1] - nose_positions[0]
            features['max_head_y_change'] = np.max(nose_positions) - np.min(nose_positions)
        
        print(f"Successfully extracted {len(features)} features")
        
        # Return both raw keypoints and extracted features
        return valid_keypoints, features
        
    except Exception as e:
        print(f"Error processing video {video_path}: {e}")
        return None, None

# Process videos and extract features
def process_videos_and_extract_features(videos, label, max_count=100):
    all_features = []
    feature_dicts = []
    video_paths = []
    
    print(f"Found {len(videos)} {label} videos, processing up to {max_count}")
    
    for i, video_path in enumerate(videos[:max_count]):
        print(f"\nProcessing video {i+1}/{min(len(videos), max_count)}: {video_path}")
        keypoints, features = extract_features_from_video(str(video_path))
        
        if features:
            # Add label and video path to features
            features['label'] = label
            features['video_path'] = str(video_path)
            
            feature_dicts.append(features)
            video_paths.append(str(video_path))
            
            # Store keypoints sequence
            if keypoints:
                all_features.append((keypoints, label))
    
    # Create DataFrame from feature dictionaries
    if feature_dicts:
        df = pd.DataFrame(feature_dicts)
        print(f"Successfully extracted features from {len(feature_dicts)} {label} videos")
        return df, all_features
    
    print(f"No features could be extracted from {label} videos")
    return None, None

# Initialize variables
combined_df = None
fall_df = None
workout_df = None

# Find all videos
print("Finding videos...")
fall_videos = list(Path(FALL_DATA_DIR).rglob("*.avi"))
workout_videos = list(Path(WORKOUT_VIDEOS_DIR).rglob("*.mp4"))

print(f"Found {len(fall_videos)} fall videos")
print(f"Found {len(workout_videos)} workout videos")

# Extract features from fall videos
print("\nExtracting features from fall videos...")
fall_df, fall_features = process_videos_and_extract_features(fall_videos, "fall")

# Extract features from workout videos
print("\nExtracting features from workout videos...")
workout_df, workout_features = process_videos_and_extract_features(workout_videos, "workout")

# Prepare to combine and save features
print("\nPreparing to save features to CSV:")
dfs_to_combine = []

if fall_df is not None:
    print(f"Fall features: {len(fall_df)} rows")
    dfs_to_combine.append(fall_df)
else:
    print("No fall features extracted successfully")



if workout_df is not None:
    print(f"Workout features: {len(workout_df)} rows")
    dfs_to_combine.append(workout_df)
else:
    print("No workout features extracted successfully")

# Save even if only some categories have data
if dfs_to_combine:
    combined_df = pd.concat(dfs_to_combine, ignore_index=True)
    csv_path = os.path.join(OUTPUT_DIR, "video_features.csv")
    combined_df.to_csv(csv_path, index=False)
    print(f"Features saved to {csv_path} with {len(combined_df)} total rows")
    
    # Display statistics
    print("\nFeature Statistics:")
    print(combined_df.groupby('label').size())
    
    # Display feature correlation matrix
    try:
        numeric_df = combined_df.select_dtypes(include=[np.number])
        plt.figure(figsize=(12, 10))
        correlation = numeric_df.corr()
        plt.imshow(correlation, cmap='coolwarm', interpolation='none')
        plt.colorbar()
        plt.xticks(range(len(correlation.columns)), correlation.columns, rotation=90)
        plt.yticks(range(len(correlation.columns)), correlation.columns)
        plt.title('Feature Correlation Matrix')
        plt.tight_layout()
        plt.show()
        
        # Visualize features with PCA
        features_for_pca = numeric_df.drop(columns=['label'], errors='ignore')
        
        # Handle missing values
        features_for_pca = features_for_pca.fillna(0)
        
        # Standardize features
        scaler = StandardScaler()
        scaled_features = scaler.fit_transform(features_for_pca)
        
        # Apply PCA
        pca = PCA(n_components=2)
        pca_result = pca.fit_transform(scaled_features)
        
        # Create DataFrame for plotting
        pca_df = pd.DataFrame({
            'PCA1': pca_result[:, 0],
            'PCA2': pca_result[:, 1],
            'label': combined_df['label']
        })
        
        # Plot PCA results
        plt.figure(figsize=(10, 8))
        for label, color in zip(['fall', 'workout'], ['red', 'green']):
            subset = pca_df[pca_df['label'] == label]
            if not subset.empty:
                plt.scatter(subset['PCA1'], subset['PCA2'], c=color, label=label, alpha=0.7)
        
        plt.title('PCA of Video Features')
        plt.xlabel(f'PCA1 ({pca.explained_variance_ratio_[0]:.2%} variance)')
        plt.ylabel(f'PCA2 ({pca.explained_variance_ratio_[1]:.2%} variance)')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.show()
        
        print(f"Total variance explained by 2 components: {sum(pca.explained_variance_ratio_):.2%}")
    
        # Feature importance analysis
        # Create feature set for binary classification (workout vs. non-workout)
        X = combined_df.select_dtypes(include=[np.number]).fillna(0)
        combined_df['is_workout'] = combined_df['label'] == 'workout'
        y = combined_df['is_workout']
        
        # Train a simple Random Forest to get feature importance
        from sklearn.ensemble import RandomForestClassifier
        
        rf = RandomForestClassifier(n_estimators=100, random_state=42)
        rf.fit(X, y)
        
        # Plot feature importance
        feature_importance = pd.DataFrame({
            'feature': X.columns,
            'importance': rf.feature_importances_
        }).sort_values('importance', ascending=False)
        
        plt.figure(figsize=(12, 6))
        plt.bar(feature_importance['feature'], feature_importance['importance'])
        plt.title('Feature Importance for Workout vs. Non-Workout Classification')
        plt.xticks(rotation=90)
        plt.tight_layout()
        plt.show()
        
        print("Top 5 most important features:")
        print(feature_importance.head(5))
    except Exception as e:
        print(f"Error during visualization or analysis: {e}")
        print("Continuing with basic results")
else:
    print("No features were successfully extracted from any videos. CSV not created.")
    
print("\nFeature extraction process complete.")
# Out:
# Checking data directories:
# FALL_DATA_DIR exists: True
# WORKOUT_VIDEOS_DIR exists: True
# OUTPUT_DIR exists: True
# Loading YOLO11 models...
# Error loading models: name 'YOLO11' is not defined
# Make sure YOLO11 is installed: pip install yolo11
# Finding videos...
# Found 190 fall videos
# Found 590 workout videos
#
# Extracting features from fall videos...
# Found 190 fall videos, processing up to 100
#
# Processing video 1/100: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (1).avi
# Video info: 320x240, 157 frames
#
# 0: 480x640 (no detections), 86.8ms
# Speed: 2.4ms preprocess, 86.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.4ms
# Speed: 2.2ms preprocess, 77.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.1ms
# Speed: 2.2ms preprocess, 60.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 55.1ms
# Speed: 2.1ms preprocess, 55.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.8ms
# Speed: 2.2ms preprocess, 57.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.6ms
# Speed: 2.1ms preprocess, 54.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.6ms
# Speed: 1.9ms preprocess, 57.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.2ms
# Speed: 2.0ms preprocess, 55.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.2ms
# Speed: 1.9ms preprocess, 51.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.3ms
# Speed: 2.1ms preprocess, 64.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.9ms
# Speed: 3.3ms preprocess, 63.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.5ms
# Speed: 1.7ms preprocess, 62.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.2ms
# Speed: 2.0ms preprocess, 60.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.3ms
# Speed: 1.7ms preprocess, 58.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.5ms
# Speed: 2.3ms preprocess, 63.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.7ms
# Speed: 2.1ms preprocess, 59.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.7ms
# Speed: 1.5ms preprocess, 51.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.2ms
# Speed: 2.1ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.2ms
# Speed: 1.6ms preprocess, 50.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.2ms
# Speed: 2.3ms preprocess, 48.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.4ms
# Speed: 1.9ms preprocess, 54.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.7ms
# Speed: 2.2ms preprocess, 53.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.5ms
# Speed: 2.1ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.0ms
# Speed: 1.9ms preprocess, 48.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.4ms
# Speed: 2.0ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.5ms
# Speed: 1.9ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.5ms
# Speed: 1.9ms preprocess, 51.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.1ms
# Speed: 1.6ms preprocess, 53.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.8ms
# Speed: 1.8ms preprocess, 52.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.7ms
# Speed: 1.9ms preprocess, 50.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (1).avi
# Person detection rate: 0.88
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 2/100: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (10).avi
# Video info: 320x240, 362 frames
#
# 0: 480x640 1 person, 54.0ms
# Speed: 2.4ms preprocess, 54.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.7ms
# Speed: 2.5ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.7ms
# Speed: 1.9ms preprocess, 49.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.0ms
# Speed: 1.6ms preprocess, 59.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.6ms
# Speed: 2.2ms preprocess, 50.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.6ms
# Speed: 2.1ms preprocess, 63.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.9ms
# Speed: 2.6ms preprocess, 52.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.7ms
# Speed: 2.5ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.8ms
# Speed: 2.1ms preprocess, 49.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.8ms
# Speed: 1.5ms preprocess, 54.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.7ms
# Speed: 1.5ms preprocess, 49.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.4ms
# Speed: 2.0ms preprocess, 56.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.3ms
# Speed: 2.0ms preprocess, 50.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.7ms
# Speed: 2.0ms preprocess, 53.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.4ms
# Speed: 2.1ms preprocess, 54.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.8ms
# Speed: 2.0ms preprocess, 50.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.3ms
# Speed: 2.0ms preprocess, 53.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.6ms
# Speed: 2.1ms preprocess, 56.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.2ms
# Speed: 1.9ms preprocess, 54.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.6ms
# Speed: 1.9ms preprocess, 51.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.9ms
# Speed: 2.3ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.0ms
# Speed: 1.8ms preprocess, 51.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.2ms
# Speed: 2.0ms preprocess, 58.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.5ms
# Speed: 2.8ms preprocess, 56.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.7ms
# Speed: 1.9ms preprocess, 54.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.7ms
# Speed: 2.4ms preprocess, 54.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.5ms
# Speed: 1.7ms preprocess, 58.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.4ms
# Speed: 2.1ms preprocess, 57.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.7ms
# Speed: 1.9ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.8ms
# Speed: 2.0ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.5ms
# Speed: 2.2ms preprocess, 58.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (10).avi
# Person detection rate: 1.00
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 3/100: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (11).avi
# Video info: 320x240, 483 frames
#
# 0: 480x640 1 person, 57.7ms
# Speed: 2.0ms preprocess, 57.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.1ms
# Speed: 2.1ms preprocess, 56.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.5ms
# Speed: 1.9ms preprocess, 56.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.4ms
# Speed: 2.1ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.9ms
# Speed: 2.2ms preprocess, 51.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.1ms
# Speed: 2.2ms preprocess, 56.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.3ms
# Speed: 2.4ms preprocess, 62.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.7ms
# Speed: 2.0ms preprocess, 57.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.8ms
# Speed: 2.0ms preprocess, 59.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.2ms
# Speed: 2.0ms preprocess, 54.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.0ms
# Speed: 2.4ms preprocess, 59.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.4ms
# Speed: 2.0ms preprocess, 64.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.9ms
# Speed: 2.2ms preprocess, 58.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.2ms
# Speed: 2.2ms preprocess, 55.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.5ms
# Speed: 2.6ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.6ms
# Speed: 2.0ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.1ms
# Speed: 2.1ms preprocess, 59.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.8ms
# Speed: 2.5ms preprocess, 54.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.9ms
# Speed: 2.1ms preprocess, 59.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.5ms
# Speed: 1.7ms preprocess, 52.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.6ms
# Speed: 2.0ms preprocess, 53.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.5ms
# Speed: 1.9ms preprocess, 56.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.5ms
# Speed: 1.7ms preprocess, 54.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.1ms
# Speed: 2.1ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.9ms
# Speed: 1.9ms preprocess, 53.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.8ms
# Speed: 2.1ms preprocess, 57.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.8ms
# Speed: 2.1ms preprocess, 53.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.7ms
# Speed: 2.1ms preprocess, 58.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (11).avi
# Person detection rate: 1.00
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 4/100: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (12).avi
# Video info: 320x240, 182 frames
#
# 0: 480x640 1 person, 56.3ms
# Speed: 2.4ms preprocess, 56.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 63.4ms
# Speed: 2.3ms preprocess, 63.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.7ms
# Speed: 1.5ms preprocess, 56.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.1ms
# Speed: 2.3ms preprocess, 56.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 54.6ms
# Speed: 2.2ms preprocess, 54.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.7ms
# Speed: 2.4ms preprocess, 60.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 50.2ms
# Speed: 2.1ms preprocess, 50.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.2ms
# Speed: 2.1ms preprocess, 56.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.4ms
# Speed: 2.1ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.3ms
# Speed: 2.0ms preprocess, 54.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.8ms
# Speed: 2.1ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.2ms
# Speed: 2.2ms preprocess, 53.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.1ms
# Speed: 2.1ms preprocess, 54.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.5ms
# Speed: 2.3ms preprocess, 56.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.0ms
# Speed: 1.8ms preprocess, 56.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.7ms
# Speed: 1.7ms preprocess, 53.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.9ms
# Speed: 2.0ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 127.1ms
# Speed: 2.0ms preprocess, 127.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.6ms
# Speed: 2.6ms preprocess, 83.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 68.9ms
# Speed: 3.2ms preprocess, 68.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.4ms
# Speed: 2.6ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.6ms
# Speed: 1.7ms preprocess, 52.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.1ms
# Speed: 2.0ms preprocess, 55.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.5ms
# Speed: 1.8ms preprocess, 52.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.5ms
# Speed: 1.9ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.4ms
# Speed: 2.2ms preprocess, 54.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.1ms
# Speed: 2.0ms preprocess, 53.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.8ms
# Speed: 1.6ms preprocess, 53.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.6ms
# Speed: 2.0ms preprocess, 53.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.9ms
# Speed: 2.1ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (12).avi
# Person detection rate: 0.44
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 5/100: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (13).avi
# Video info: 320x240, 244 frames
#
# 0: 480x640 1 person, 58.0ms
# Speed: 2.2ms preprocess, 58.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 55.0ms
# Speed: 1.8ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.0ms
# Speed: 1.7ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.5ms
# Speed: 2.7ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.9ms
# Speed: 2.3ms preprocess, 53.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 51.8ms
# Speed: 2.6ms preprocess, 51.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.0ms
# Speed: 2.3ms preprocess, 52.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.6ms
# Speed: 2.1ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.1ms
# Speed: 2.1ms preprocess, 63.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.3ms
# Speed: 2.4ms preprocess, 54.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.3ms
# Speed: 2.2ms preprocess, 56.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 53.1ms
# Speed: 1.6ms preprocess, 53.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.3ms
# Speed: 2.4ms preprocess, 55.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.2ms
# Speed: 2.1ms preprocess, 59.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.4ms
# Speed: 2.0ms preprocess, 53.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.6ms
# Speed: 2.2ms preprocess, 53.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.9ms
# Speed: 2.2ms preprocess, 52.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.0ms
# Speed: 2.2ms preprocess, 55.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.3ms
# Speed: 1.8ms preprocess, 54.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.6ms
# Speed: 2.5ms preprocess, 54.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.1ms
# Speed: 2.2ms preprocess, 56.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.8ms
# Speed: 2.3ms preprocess, 55.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.0ms
# Speed: 2.2ms preprocess, 52.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.5ms
# Speed: 2.8ms preprocess, 54.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.5ms
# Speed: 2.3ms preprocess, 53.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.2ms
# Speed: 2.4ms preprocess, 56.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.8ms
# Speed: 1.9ms preprocess, 54.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.5ms
# Speed: 2.1ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.3ms
# Speed: 2.0ms preprocess, 52.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.4ms
# Speed: 2.0ms preprocess, 53.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (13).avi
# Person detection rate: 0.44
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 6/100: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (14).avi
# Video info: 320x240, 176 frames
#
# 0: 480x640 1 person, 51.4ms
# Speed: 2.2ms preprocess, 51.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.5ms
# Speed: 2.1ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.3ms
# Speed: 2.1ms preprocess, 51.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.5ms
# Speed: 3.1ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.6ms
# Speed: 1.8ms preprocess, 51.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.9ms
# Speed: 2.4ms preprocess, 55.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.0ms
# Speed: 1.7ms preprocess, 51.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.0ms
# Speed: 2.2ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.2ms
# Speed: 2.0ms preprocess, 56.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.4ms
# Speed: 3.0ms preprocess, 64.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.4ms
# Speed: 2.2ms preprocess, 60.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.8ms
# Speed: 2.0ms preprocess, 55.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.2ms
# Speed: 2.0ms preprocess, 52.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.3ms
# Speed: 2.1ms preprocess, 52.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.3ms
# Speed: 2.9ms preprocess, 55.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.7ms
# Speed: 2.1ms preprocess, 59.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.9ms
# Speed: 2.8ms preprocess, 60.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.1ms
# Speed: 2.7ms preprocess, 57.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.3ms
# Speed: 2.6ms preprocess, 58.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.5ms
# Speed: 1.8ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.6ms
# Speed: 2.1ms preprocess, 50.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.5ms
# Speed: 2.6ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.6ms
# Speed: 1.8ms preprocess, 51.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.9ms
# Speed: 2.1ms preprocess, 53.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.3ms
# Speed: 1.8ms preprocess, 55.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.2ms
# Speed: 2.0ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.7ms
# Speed: 1.6ms preprocess, 52.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.3ms
# Speed: 2.2ms preprocess, 56.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.1ms
# Speed: 2.1ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.4ms
# Speed: 2.3ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (14).avi
# Person detection rate: 1.00
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 7/100: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (15).avi
# Video info: 320x240, 140 frames
#
# 0: 480x640 1 person, 57.1ms
# Speed: 2.3ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.1ms
# Speed: 2.1ms preprocess, 56.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.5ms
# Speed: 2.1ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.1ms
# Speed: 2.1ms preprocess, 61.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.8ms
# Speed: 1.9ms preprocess, 65.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.8ms
# Speed: 2.1ms preprocess, 60.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.4ms
# Speed: 1.7ms preprocess, 56.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.3ms
# Speed: 2.4ms preprocess, 56.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.5ms
# Speed: 2.5ms preprocess, 51.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.8ms
# Speed: 2.4ms preprocess, 65.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.3ms
# Speed: 2.1ms preprocess, 53.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.0ms
# Speed: 1.8ms preprocess, 55.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 163.7ms
# Speed: 2.2ms preprocess, 163.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.9ms
# Speed: 5.4ms preprocess, 56.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.7ms
# Speed: 4.4ms preprocess, 88.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.6ms
# Speed: 2.1ms preprocess, 56.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.2ms
# Speed: 2.2ms preprocess, 63.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.0ms
# Speed: 2.3ms preprocess, 62.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.6ms
# Speed: 2.4ms preprocess, 54.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.6ms
# Speed: 2.6ms preprocess, 61.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.8ms
# Speed: 2.2ms preprocess, 58.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.9ms
# Speed: 2.1ms preprocess, 61.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.1ms
# Speed: 2.4ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.5ms
# Speed: 2.1ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.6ms
# Speed: 2.1ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.3ms
# Speed: 2.0ms preprocess, 54.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.7ms
# Speed: 3.0ms preprocess, 63.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.8ms
# Speed: 2.1ms preprocess, 56.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.5ms
# Speed: 2.4ms preprocess, 58.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.1ms
# Speed: 2.9ms preprocess, 64.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.8ms
# Speed: 2.8ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (15).avi
# Person detection rate: 1.00
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 8/100: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (16).avi
# Video info: 320x240, 177 frames
#
# 0: 480x640 1 person, 63.1ms
# Speed: 2.2ms preprocess, 63.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.5ms
# Speed: 2.2ms preprocess, 68.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.1ms
# Speed: 2.0ms preprocess, 64.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.9ms
# Speed: 2.1ms preprocess, 61.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.7ms
# Speed: 2.7ms preprocess, 64.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.5ms
# Speed: 2.9ms preprocess, 63.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.7ms
# Speed: 2.6ms preprocess, 62.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.9ms
# Speed: 2.5ms preprocess, 61.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.0ms
# Speed: 2.5ms preprocess, 64.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.0ms
# Speed: 2.1ms preprocess, 62.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.3ms
# Speed: 2.6ms preprocess, 63.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.1ms
# Speed: 2.7ms preprocess, 59.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.7ms
# Speed: 2.6ms preprocess, 63.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.2ms
# Speed: 2.6ms preprocess, 61.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.0ms
# Speed: 2.6ms preprocess, 63.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.0ms
# Speed: 2.6ms preprocess, 63.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.0ms
# Speed: 2.7ms preprocess, 61.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.0ms
# Speed: 2.5ms preprocess, 59.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.8ms
# Speed: 2.6ms preprocess, 62.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.4ms
# Speed: 2.1ms preprocess, 59.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.6ms
# Speed: 2.6ms preprocess, 61.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.7ms
# Speed: 2.1ms preprocess, 58.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.7ms
# Speed: 2.4ms preprocess, 62.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.7ms
# Speed: 2.8ms preprocess, 57.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.2ms
# Speed: 2.7ms preprocess, 73.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.9ms
# Speed: 2.6ms preprocess, 61.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.9ms
# Speed: 2.9ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.3ms
# Speed: 2.8ms preprocess, 57.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.6ms
# Speed: 2.8ms preprocess, 62.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.1ms
# Speed: 2.7ms preprocess, 61.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.9ms
# Speed: 2.2ms preprocess, 60.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (16).avi
# Person detection rate: 1.00
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 9/100: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (17).avi
# Video info: 320x240, 158 frames
#
# 0: 480x640 1 person, 56.1ms
# Speed: 2.1ms preprocess, 56.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.2ms
# Speed: 2.5ms preprocess, 63.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.4ms
# Speed: 2.3ms preprocess, 56.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.4ms
# Speed: 2.9ms preprocess, 63.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.8ms
# Speed: 2.6ms preprocess, 61.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.8ms
# Speed: 2.7ms preprocess, 62.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.4ms
# Speed: 2.1ms preprocess, 58.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.0ms
# Speed: 2.7ms preprocess, 61.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.2ms
# Speed: 3.0ms preprocess, 63.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 64.5ms
# Speed: 2.6ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.2ms
# Speed: 2.8ms preprocess, 60.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.9ms
# Speed: 3.2ms preprocess, 64.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.1ms
# Speed: 2.9ms preprocess, 126.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.4ms
# Speed: 7.6ms preprocess, 123.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.9ms
# Speed: 2.8ms preprocess, 89.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 67.5ms
# Speed: 2.3ms preprocess, 67.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.0ms
# Speed: 2.7ms preprocess, 63.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.4ms
# Speed: 2.6ms preprocess, 66.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.8ms
# Speed: 3.2ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.6ms
# Speed: 2.8ms preprocess, 71.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.6ms
# Speed: 2.7ms preprocess, 64.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.5ms
# Speed: 2.9ms preprocess, 72.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.6ms
# Speed: 3.4ms preprocess, 62.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 67.3ms
# Speed: 2.8ms preprocess, 67.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.6ms
# Speed: 3.0ms preprocess, 60.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.8ms
# Speed: 2.8ms preprocess, 68.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.7ms
# Speed: 3.0ms preprocess, 65.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.8ms
# Speed: 2.7ms preprocess, 68.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.0ms
# Speed: 2.8ms preprocess, 60.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.6ms
# Speed: 2.9ms preprocess, 63.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.1ms
# Speed: 2.3ms preprocess, 62.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.5ms
# Speed: 3.0ms preprocess, 65.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (17).avi
# Person detection rate: 1.00
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 10/100: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (18).avi
# Video info: 320x240, 269 frames
#
# 0: 480x640 1 person, 61.2ms
# Speed: 2.4ms preprocess, 61.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.6ms
# Speed: 2.8ms preprocess, 64.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.3ms
# Speed: 2.7ms preprocess, 60.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.4ms
# Speed: 3.1ms preprocess, 62.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.8ms
# Speed: 3.1ms preprocess, 61.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.4ms
# Speed: 2.6ms preprocess, 64.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.2ms
# Speed: 2.8ms preprocess, 61.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.8ms
# Speed: 2.7ms preprocess, 64.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.2ms
# Speed: 2.7ms preprocess, 63.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.5ms
# Speed: 2.7ms preprocess, 64.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.6ms
# Speed: 2.8ms preprocess, 66.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.4ms
# Speed: 3.2ms preprocess, 59.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.1ms
# Speed: 2.9ms preprocess, 65.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.7ms
# Speed: 2.2ms preprocess, 61.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 67.6ms
# Speed: 2.8ms preprocess, 67.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.9ms
# Speed: 3.3ms preprocess, 64.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 67.4ms
# Speed: 3.0ms preprocess, 67.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.9ms
# Speed: 2.4ms preprocess, 63.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.9ms
# Speed: 2.2ms preprocess, 71.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 67.0ms
# Speed: 3.1ms preprocess, 67.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.4ms
# Speed: 3.7ms preprocess, 74.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.9ms
# Speed: 3.1ms preprocess, 70.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.7ms
# Speed: 3.0ms preprocess, 68.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.8ms
# Speed: 3.0ms preprocess, 65.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.8ms
# Speed: 3.2ms preprocess, 70.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.7ms
# Speed: 3.2ms preprocess, 64.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.0ms
# Speed: 3.0ms preprocess, 70.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.3ms
# Speed: 2.4ms preprocess, 66.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.5ms
# Speed: 3.3ms preprocess, 68.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.8ms
# Speed: 3.1ms preprocess, 61.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 70.9ms
# Speed: 3.3ms preprocess, 70.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (18).avi
# Person detection rate: 1.00
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 11/100: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (19).avi
# Video info: 320x240, 213 frames
#
# 0: 480x640 2 persons, 62.6ms
# Speed: 3.9ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 102.2ms
# Speed: 2.6ms preprocess, 102.2ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 150.8ms
# Speed: 4.5ms preprocess, 150.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.3ms
# Speed: 3.3ms preprocess, 83.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 66.5ms
# Speed: 2.9ms preprocess, 66.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.0ms
# Speed: 3.9ms preprocess, 73.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.9ms
# Speed: 3.2ms preprocess, 70.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 67.1ms
# Speed: 2.9ms preprocess, 67.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.7ms
# Speed: 3.1ms preprocess, 72.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 66.5ms
# Speed: 3.5ms preprocess, 66.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.9ms
# Speed: 3.4ms preprocess, 69.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.3ms
# Speed: 3.0ms preprocess, 64.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 67.6ms
# Speed: 3.3ms preprocess, 67.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.3ms
# Speed: 3.2ms preprocess, 65.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 69.9ms
# Speed: 2.9ms preprocess, 69.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.9ms
# Speed: 3.0ms preprocess, 62.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 67.1ms
# Speed: 2.9ms preprocess, 67.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.5ms
# Speed: 2.1ms preprocess, 56.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.8ms
# Speed: 2.3ms preprocess, 52.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 47.0ms
# Speed: 2.5ms preprocess, 47.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.8ms
# Speed: 1.8ms preprocess, 56.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.8ms
# Speed: 2.2ms preprocess, 54.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.3ms
# Speed: 3.3ms preprocess, 55.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.2ms
# Speed: 2.1ms preprocess, 54.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.3ms
# Speed: 2.3ms preprocess, 58.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.2ms
# Speed: 1.9ms preprocess, 54.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.7ms
# Speed: 2.5ms preprocess, 57.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.0ms
# Speed: 2.2ms preprocess, 50.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.2ms
# Speed: 2.9ms preprocess, 52.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (19).avi
# Person detection rate: 1.00
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 12/100: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (2).avi
# Video info: 320x240, 306 frames
#
# 0: 480x640 1 person, 53.7ms
# Speed: 2.2ms preprocess, 53.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.2ms
# Speed: 2.1ms preprocess, 54.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.1ms
# ...
#
# 0: 480x640 2 persons, 51.7ms
# Speed: 2.2ms preprocess, 51.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.9ms
# Speed: 2.1ms preprocess, 64.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 124.6ms
# Speed: 5.9ms preprocess, 124.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.5ms
# Speed: 2.9ms preprocess, 84.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.7ms
# Speed: 2.8ms preprocess, 58.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.6ms
# Speed: 2.2ms preprocess, 59.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.1ms
# Speed: 2.5ms preprocess, 60.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.1ms
# Speed: 2.2ms preprocess, 61.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.6ms
# Speed: 2.2ms preprocess, 52.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.2ms
# Speed: 2.2ms preprocess, 54.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.4ms
# Speed: 2.1ms preprocess, 50.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.8ms
# Speed: 2.3ms preprocess, 56.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.7ms
# Speed: 2.2ms preprocess, 51.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 53.3ms
# Speed: 2.1ms preprocess, 53.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.9ms
# Speed: 2.0ms preprocess, 48.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.2ms
# Speed: 1.5ms preprocess, 54.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.7ms
# Speed: 1.9ms preprocess, 46.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.6ms
# Speed: 1.9ms preprocess, 50.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.6ms
# Speed: 1.9ms preprocess, 45.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.2ms
# Speed: 1.7ms preprocess, 48.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.0ms
# Speed: 2.1ms preprocess, 46.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.9ms
# Speed: 2.0ms preprocess, 49.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (9).avi
# Person detection rate: 1.00
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 49/100: ..\data\le2i\Coffee_room_02\Coffee_room_02\Videos\video (49).avi
# Video info: 320x240, 492 frames
#
# 0: 480x640 1 person, 52.1ms
# Speed: 2.2ms preprocess, 52.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 52.3ms
# Speed: 2.2ms preprocess, 52.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.6ms
# Speed: 2.7ms preprocess, 52.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 58.9ms
# Speed: 1.9ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.4ms
# Speed: 2.4ms preprocess, 52.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.5ms
# Speed: 2.3ms preprocess, 48.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.2ms
# Speed: 2.0ms preprocess, 50.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.3ms
# Speed: 2.3ms preprocess, 58.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.1ms
# Speed: 2.2ms preprocess, 114.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.6ms
# Speed: 2.9ms preprocess, 68.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.3ms
# Speed: 2.1ms preprocess, 61.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.9ms
# Speed: 2.0ms preprocess, 51.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 47.1ms
# Speed: 2.4ms preprocess, 47.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.8ms
# Speed: 1.5ms preprocess, 48.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Speed: 1.8ms preprocess, 41.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.5ms
# Speed: 2.0ms preprocess, 49.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 55.1ms
# Speed: 2.0ms preprocess, 55.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.7ms
# Speed: 2.3ms preprocess, 57.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 52.8ms
# Speed: 2.6ms preprocess, 52.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 71.5ms
# Speed: 3.1ms preprocess, 71.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 65.3ms
# Speed: 2.9ms preprocess, 65.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 66.1ms
# Speed: 2.9ms preprocess, 66.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 61.9ms
# Speed: 2.9ms preprocess, 61.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 62.8ms
# Speed: 3.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.6ms
# Speed: 2.4ms preprocess, 57.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.1ms
# Speed: 2.8ms preprocess, 60.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.8ms
# Speed: 2.7ms preprocess, 56.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.4ms
# Speed: 2.2ms preprocess, 59.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.4ms
# Speed: 2.9ms preprocess, 58.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 63.8ms
# Speed: 2.8ms preprocess, 63.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.9ms
# Speed: 2.7ms preprocess, 59.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.2ms
# Speed: 2.8ms preprocess, 65.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (49).avi
# Person detection rate: 1.00
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 50/100: ..\data\le2i\Coffee_room_02\Coffee_room_02\Videos\video (50).avi
# Video info: 320x240, 1954 frames
#
# 0: 480x640 1 person, 55.9ms
# Speed: 2.8ms preprocess, 55.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 61.0ms
# Speed: 2.8ms preprocess, 61.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.8ms
# Speed: 2.9ms preprocess, 58.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.8ms
# Speed: 3.2ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.0ms
# Speed: 2.9ms preprocess, 60.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 62.5ms
# Speed: 2.6ms preprocess, 62.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.8ms
# Speed: 2.8ms preprocess, 56.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 63.4ms
# Speed: 2.7ms preprocess, 63.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.8ms
# Speed: 2.8ms preprocess, 58.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.6ms
# Speed: 2.7ms preprocess, 59.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.8ms
# Speed: 2.7ms preprocess, 50.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 58.3ms
# Speed: 2.7ms preprocess, 58.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.7ms
# Speed: 2.8ms preprocess, 54.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.6ms
# Speed: 2.7ms preprocess, 59.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.4ms
# Speed: 2.5ms preprocess, 58.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.5ms
# Speed: 2.3ms preprocess, 59.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.6ms
# Speed: 2.2ms preprocess, 56.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.7ms
# Speed: 2.2ms preprocess, 60.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.6ms
# Speed: 2.1ms preprocess, 61.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.9ms
# Speed: 2.9ms preprocess, 61.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.0ms
# Speed: 2.2ms preprocess, 60.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.4ms
# Speed: 3.0ms preprocess, 63.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.5ms
# Speed: 2.1ms preprocess, 57.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 60.6ms
# Speed: 2.4ms preprocess, 60.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 57.7ms
# Speed: 2.7ms preprocess, 57.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.0ms
# Speed: 3.4ms preprocess, 65.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.7ms
# Speed: 3.3ms preprocess, 62.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.2ms
# Speed: 3.7ms preprocess, 68.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.3ms
# Speed: 3.2ms preprocess, 70.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.9ms
# Speed: 3.1ms preprocess, 68.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 67.0ms
# Speed: 3.1ms preprocess, 67.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.1ms
# Speed: 3.4ms preprocess, 73.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (50).avi
# Person detection rate: 1.00
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 51/100: ..\data\le2i\Coffee_room_02\Coffee_room_02\Videos\video (51).avi
# Video info: 320x240, 203 frames
#
# 0: 480x640 (no detections), 65.2ms
# Speed: 3.3ms preprocess, 65.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.8ms
# Speed: 3.0ms preprocess, 73.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 64.9ms
# Speed: 2.5ms preprocess, 64.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 69.5ms
# Speed: 3.1ms preprocess, 69.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.9ms
# Speed: 3.9ms preprocess, 72.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.2ms
# Speed: 3.1ms preprocess, 71.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.6ms
# Speed: 3.0ms preprocess, 64.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.6ms
# Speed: 2.5ms preprocess, 69.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.9ms
# Speed: 3.1ms preprocess, 65.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.3ms
# Speed: 3.7ms preprocess, 70.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.0ms
# Speed: 3.1ms preprocess, 66.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.3ms
# Speed: 2.6ms preprocess, 69.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.0ms
# Speed: 2.9ms preprocess, 68.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.6ms
# Speed: 3.0ms preprocess, 72.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.4ms
# Speed: 3.4ms preprocess, 64.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.7ms
# Speed: 3.1ms preprocess, 69.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.3ms
# Speed: 3.3ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.8ms
# Speed: 3.0ms preprocess, 106.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.7ms
# Speed: 4.9ms preprocess, 112.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.7ms
# Speed: 4.8ms preprocess, 69.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.8ms
# Speed: 3.3ms preprocess, 79.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.2ms
# Speed: 3.4ms preprocess, 68.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.2ms
# Speed: 3.1ms preprocess, 65.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.4ms
# Speed: 3.3ms preprocess, 66.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.7ms
# Speed: 3.0ms preprocess, 63.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.4ms
# Speed: 2.8ms preprocess, 66.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.1ms
# Speed: 3.1ms preprocess, 61.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 78.9ms
# Speed: 3.0ms preprocess, 78.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.7ms
# Speed: 3.0ms preprocess, 91.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.7ms
# Speed: 3.6ms preprocess, 86.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.7ms
# Speed: 3.2ms preprocess, 65.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.5ms
# Speed: 3.0ms preprocess, 71.5ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (51).avi
# Person detection rate: 0.88
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 52/100: ..\data\le2i\Coffee_room_02\Coffee_room_02\Videos\video (52).avi
# Video info: 320x240, 215 frames
#
# 0: 480x640 1 person, 77.5ms
# Speed: 8.2ms preprocess, 77.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
