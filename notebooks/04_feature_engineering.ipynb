# %% [markdown]
# ## 4. Feature Engineering
#
# ### `04_feature_engineering.ipynb`

# %%
# Import necessary libraries
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from ultralytics import YOLO
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
# %matplotlib inline

# Set paths
FALL_DATA_DIR = "../data/le2i"
WORKOUT_VIDEOS_DIR = "../data/workout_videos"
OUTPUT_DIR = "../outputs/features"
os.makedirs(OUTPUT_DIR, exist_ok=True)

print(f"Checking data directories:")
print(f"FALL_DATA_DIR exists: {os.path.exists(FALL_DATA_DIR)}")
print(f"WORKOUT_VIDEOS_DIR exists: {os.path.exists(WORKOUT_VIDEOS_DIR)}")
print(f"OUTPUT_DIR exists: {os.path.exists(OUTPUT_DIR)}")

# Initialize YOLO11 models
print("Loading YOLO11 models...")
try:
    yolo_model = YOLO('yolo11n.pt')  # For person detection
    yolo_pose_model = YOLO('yolo11n-pose.pt')  # For pose estimation
    print("Models loaded successfully")
except Exception as e:
    print(f"Error loading models: {e}")
    print("Make sure YOLO11 is installed: pip install yolo11")

# Function to extract features from a video
def extract_features_from_video(video_path, num_frames=16):
    """Extract pose and motion features from a video using YOLO11"""
    try:
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            print(f"Error: Could not open video {video_path}")
            return None, None
            
        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        
        print(f"Video info: {frame_width}x{frame_height}, {frame_count} frames")
        
        # Calculate frame indices to sample
        indices = np.linspace(0, frame_count-1, num_frames, dtype=int)
        
        # Keypoint sequences
        keypoint_sequence = []
        is_pose_detected = []
        person_detected = []
        
        for idx in indices:
            cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
            ret, frame = cap.read()
            
            if not ret:
                # If frame reading fails, add placeholder
                keypoint_sequence.append(None)
                is_pose_detected.append(False)
                person_detected.append(False)
                continue
            
            # Person detection with YOLO11
            person_results = yolo_model(frame, classes=[0], conf=0.5)
            
            person_found = False
            
            if len(person_results[0].boxes) > 0:
                person_found = True
                person_detected.append(True)
            else:
                person_detected.append(False)
            
            # Pose detection with YOLO11 pose
            pose_results = yolo_pose_model(frame)
            
            if len(pose_results[0].keypoints.data) > 0:
                is_pose_detected.append(True)
                
                # Get the pose with highest confidence (usually the largest one)
                best_pose_idx = 0
                if len(pose_results[0].boxes) > 1:
                    # If multiple poses, get the one with highest confidence
                    confidences = [box.conf.item() for box in pose_results[0].boxes]
                    best_pose_idx = np.argmax(confidences)
                
                # Extract keypoints for the best pose
                pose_keypoints = pose_results[0].keypoints.data[best_pose_idx]
                
                # Convert to a flat list format
                frame_keypoints = []
                for kp_idx in range(pose_keypoints.shape[0]):
                    x, y, conf = pose_keypoints[kp_idx].tolist()
                    # Normalize coordinates
                    frame_keypoints.extend([
                        float(x) / frame_width,
                        float(y) / frame_height,
                        0.0,  # YOLO11 doesn't provide z-coordinate
                        float(conf)
                    ])
                
                keypoint_sequence.append(frame_keypoints)
            else:
                is_pose_detected.append(False)
                keypoint_sequence.append(None)
        
        cap.release()
        
        # Statistics
        pose_detection_rate = sum(is_pose_detected) / len(is_pose_detected) if is_pose_detected else 0
        person_detection_rate = sum(person_detected) / len(person_detected) if person_detected else 0
        
        print(f"Video: {os.path.basename(video_path)}")
        print(f"Person detection rate: {person_detection_rate:.2f}")
        print(f"Pose detection rate: {pose_detection_rate:.2f}")
        
        # If no poses detected, return None
        if not any(is_pose_detected):
            print("No poses detected in this video")
            return None, None
        
        # Calculate pose-based features
        valid_keypoints = [kp for kp in keypoint_sequence if kp is not None]
        
        if not valid_keypoints:
            print("No valid keypoints found")
            return None, None
        
        # Create features
        features = {}
        
        # 1. Keypoint velocities
        if len(valid_keypoints) >= 2:
            velocities = []
            for i in range(1, len(valid_keypoints)):
                frame_velocities = []
                for j in range(0, len(valid_keypoints[i]), 4):  # Each keypoint has 4 values (x,y,z,v)
                    if j+3 < len(valid_keypoints[i]) and j+3 < len(valid_keypoints[i-1]):
                        # Calculate Euclidean distance between consecutive frames
                        dx = valid_keypoints[i][j] - valid_keypoints[i-1][j]
                        dy = valid_keypoints[i][j+1] - valid_keypoints[i-1][j+1]
                        # Note: YOLO11 doesn't have z-coordinate, so we use 0
                        velocity = np.sqrt(dx**2 + dy**2)
                        frame_velocities.append(velocity)
                
                if frame_velocities:
                    velocities.append(frame_velocities)
            
            if velocities:
                features['max_velocity'] = np.max([np.max(v) if v else 0 for v in velocities])
                features['mean_velocity'] = np.mean([np.mean(v) if v else 0 for v in velocities])
                features['std_velocity'] = np.std([np.std(v) if v else 0 for v in velocities]) if len(velocities) > 1 else 0
        
        # 2. Pose height variation
        heights = []
        for kp in valid_keypoints:
            y_values = [kp[i+1] for i in range(0, len(kp), 4)]
            if y_values:
                height = max(y_values) - min(y_values)
                heights.append(height)
        
        if heights:
            features['max_height'] = np.max(heights)
            features['min_height'] = np.min(heights)
            features['height_range'] = np.max(heights) - np.min(heights)
        
        # 3. Pose width variation
        widths = []
        for kp in valid_keypoints:
            x_values = [kp[i] for i in range(0, len(kp), 4)]
            if x_values:
                width = max(x_values) - min(x_values)
                widths.append(width)
        
        if widths:
            features['max_width'] = np.max(widths)
            features['min_width'] = np.min(widths)
            features['width_range'] = np.max(widths) - np.min(widths)
        
        # 4. Vertical position change (for falls)
        # Note: In YOLO11 pose, nose is keypoint index 0
        nose_positions = []
        for kp in valid_keypoints:
            if len(kp) >= 4:  # Nose is first landmark
                nose_positions.append(kp[1])  # y-coordinate of nose
        
        if nose_positions and len(nose_positions) >= 2:
            features['head_y_change'] = nose_positions[-1] - nose_positions[0]
            features['max_head_y_change'] = np.max(nose_positions) - np.min(nose_positions)
        
        print(f"Successfully extracted {len(features)} features")
        
        # Return both raw keypoints and extracted features
        return valid_keypoints, features
        
    except Exception as e:
        print(f"Error processing video {video_path}: {e}")
        return None, None

# Process videos and extract features
def process_videos_and_extract_features(videos, label, max_count=300):
    all_features = []
    feature_dicts = []
    video_paths = []
    
    print(f"Found {len(videos)} {label} videos, processing up to {max_count}")
    
    for i, video_path in enumerate(videos[:max_count]):
        print(f"\nProcessing video {i+1}/{min(len(videos), max_count)}: {video_path}")
        keypoints, features = extract_features_from_video(str(video_path))
        
        if features:
            # Add label and video path to features
            features['label'] = label
            features['video_path'] = str(video_path)
            
            feature_dicts.append(features)
            video_paths.append(str(video_path))
            
            # Store keypoints sequence
            if keypoints:
                all_features.append((keypoints, label))
    
    # Create DataFrame from feature dictionaries
    if feature_dicts:
        df = pd.DataFrame(feature_dicts)
        print(f"Successfully extracted features from {len(feature_dicts)} {label} videos")
        return df, all_features
    
    print(f"No features could be extracted from {label} videos")
    return None, None

# Initialize variables
combined_df = None
fall_df = None
workout_df = None

# Find all videos
print("Finding videos...")
fall_videos = list(Path(FALL_DATA_DIR).rglob("*.avi"))
workout_videos = list(Path(WORKOUT_VIDEOS_DIR).rglob("*.mp4"))

print(f"Found {len(fall_videos)} fall videos")
print(f"Found {len(workout_videos)} workout videos")

# Extract features from fall videos
print("\nExtracting features from fall videos...")
fall_df, fall_features = process_videos_and_extract_features(fall_videos, "fall")

# Extract features from workout videos
print("\nExtracting features from workout videos...")
workout_df, workout_features = process_videos_and_extract_features(workout_videos, "workout")

# Prepare to combine and save features
print("\nPreparing to save features to CSV:")
dfs_to_combine = []

if fall_df is not None:
    print(f"Fall features: {len(fall_df)} rows")
    dfs_to_combine.append(fall_df)
else:
    print("No fall features extracted successfully")



if workout_df is not None:
    print(f"Workout features: {len(workout_df)} rows")
    dfs_to_combine.append(workout_df)
else:
    print("No workout features extracted successfully")

# Save even if only some categories have data
if dfs_to_combine:
    combined_df = pd.concat(dfs_to_combine, ignore_index=True)
    csv_path = os.path.join(OUTPUT_DIR, "video_features.csv")
    combined_df.to_csv(csv_path, index=False)
    print(f"Features saved to {csv_path} with {len(combined_df)} total rows")
    
    # Display statistics
    print("\nFeature Statistics:")
    print(combined_df.groupby('label').size())
    
    # Display feature correlation matrix
    try:
        numeric_df = combined_df.select_dtypes(include=[np.number])
        plt.figure(figsize=(12, 10))
        correlation = numeric_df.corr()
        plt.imshow(correlation, cmap='coolwarm', interpolation='none')
        plt.colorbar()
        plt.xticks(range(len(correlation.columns)), correlation.columns, rotation=90)
        plt.yticks(range(len(correlation.columns)), correlation.columns)
        plt.title('Feature Correlation Matrix')
        plt.tight_layout()
        plt.show()
        
        # Visualize features with PCA
        features_for_pca = numeric_df.drop(columns=['label'], errors='ignore')
        
        # Handle missing values
        features_for_pca = features_for_pca.fillna(0)
        
        # Standardize features
        scaler = StandardScaler()
        scaled_features = scaler.fit_transform(features_for_pca)
        
        # Apply PCA
        pca = PCA(n_components=2)
        pca_result = pca.fit_transform(scaled_features)
        
        # Create DataFrame for plotting
        pca_df = pd.DataFrame({
            'PCA1': pca_result[:, 0],
            'PCA2': pca_result[:, 1],
            'label': combined_df['label']
        })
        
        # Plot PCA results
        plt.figure(figsize=(10, 8))
        for label, color in zip(['fall', 'workout'], ['red', 'green']):
            subset = pca_df[pca_df['label'] == label]
            if not subset.empty:
                plt.scatter(subset['PCA1'], subset['PCA2'], c=color, label=label, alpha=0.7)
        
        plt.title('PCA of Video Features')
        plt.xlabel(f'PCA1 ({pca.explained_variance_ratio_[0]:.2%} variance)')
        plt.ylabel(f'PCA2 ({pca.explained_variance_ratio_[1]:.2%} variance)')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.show()
        
        print(f"Total variance explained by 2 components: {sum(pca.explained_variance_ratio_):.2%}")
    
        # Feature importance analysis
        # Create feature set for binary classification (workout vs. non-workout)
        X = combined_df.select_dtypes(include=[np.number]).fillna(0)
        combined_df['is_workout'] = combined_df['label'] == 'workout'
        y = combined_df['is_workout']
        
        # Train a simple Random Forest to get feature importance
        from sklearn.ensemble import RandomForestClassifier
        
        rf = RandomForestClassifier(n_estimators=100, random_state=42)
        rf.fit(X, y)
        
        # Plot feature importance
        feature_importance = pd.DataFrame({
            'feature': X.columns,
            'importance': rf.feature_importances_
        }).sort_values('importance', ascending=False)
        
        plt.figure(figsize=(12, 6))
        plt.bar(feature_importance['feature'], feature_importance['importance'])
        plt.title('Feature Importance for Workout vs. Non-Workout Classification')
        plt.xticks(rotation=90)
        plt.tight_layout()
        plt.show()
        
        print("Top 5 most important features:")
        print(feature_importance.head(5))
    except Exception as e:
        print(f"Error during visualization or analysis: {e}")
        print("Continuing with basic results")
else:
    print("No features were successfully extracted from any videos. CSV not created.")
    
print("\nFeature extraction process complete.")
# Out:
# Checking data directories:
# FALL_DATA_DIR exists: True
# WORKOUT_VIDEOS_DIR exists: True
# OUTPUT_DIR exists: True
# Loading YOLO11 models...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n-pose.pt to 'yolo11n-pose.pt'...
# 100%|█████████████████████████████████████████████████████████████████████████| 5.97M/5.97M [00:05<00:00, 1.20MB/s]
# Models loaded successfully
# Finding videos...
# Found 190 fall videos
# Found 590 workout videos
#
# Extracting features from fall videos...
# Found 190 fall videos, processing up to 300
#
# Processing video 1/190: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (1).avi
# Video info: 320x240, 157 frames
#
# 0: 480x640 (no detections), 168.3ms
# Speed: 5.3ms preprocess, 168.3ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 117.6ms
# Speed: 3.5ms preprocess, 117.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.5ms
# Speed: 4.0ms preprocess, 122.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.4ms
# Speed: 2.7ms preprocess, 122.4ms inference, 17.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.9ms
# Speed: 4.2ms preprocess, 106.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.0ms
# Speed: 2.8ms preprocess, 100.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.9ms
# Speed: 7.5ms preprocess, 118.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 137.1ms
# Speed: 2.4ms preprocess, 137.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.6ms
# Speed: 2.1ms preprocess, 122.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 130.8ms
# Speed: 2.4ms preprocess, 130.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.4ms
# Speed: 3.0ms preprocess, 124.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 137.7ms
# Speed: 2.9ms preprocess, 137.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.3ms
# Speed: 2.7ms preprocess, 94.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.6ms
# Speed: 2.6ms preprocess, 98.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.5ms
# Speed: 5.2ms preprocess, 96.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.5ms
# Speed: 4.4ms preprocess, 98.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.7ms
# Speed: 3.7ms preprocess, 95.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.4ms
# Speed: 2.7ms preprocess, 111.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.0ms
# Speed: 3.5ms preprocess, 105.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.0ms
# Speed: 2.7ms preprocess, 119.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 134.7ms
# Speed: 3.2ms preprocess, 134.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.6ms
# Speed: 2.7ms preprocess, 124.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.0ms
# Speed: 2.9ms preprocess, 111.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.7ms
# Speed: 3.4ms preprocess, 118.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.5ms
# Speed: 2.7ms preprocess, 107.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 142.1ms
# Speed: 2.9ms preprocess, 142.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 116.9ms
# Speed: 2.9ms preprocess, 116.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 377.1ms
# Speed: 8.4ms preprocess, 377.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 149.5ms
# Speed: 4.8ms preprocess, 149.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 155.7ms
# Speed: 4.0ms preprocess, 155.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.8ms
# Speed: 9.9ms preprocess, 117.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.2ms
# Speed: 1.8ms preprocess, 121.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (1).avi
# Person detection rate: 0.88
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 2/190: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (10).avi
# Video info: 320x240, 362 frames
#
# 0: 480x640 1 person, 104.9ms
# Speed: 2.9ms preprocess, 104.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.8ms
# Speed: 1.9ms preprocess, 125.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.0ms
# Speed: 2.4ms preprocess, 115.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.2ms
# Speed: 2.3ms preprocess, 122.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.7ms
# Speed: 3.1ms preprocess, 107.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.3ms
# Speed: 2.4ms preprocess, 120.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.5ms
# Speed: 2.7ms preprocess, 109.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.3ms
# Speed: 2.3ms preprocess, 114.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.6ms
# Speed: 2.4ms preprocess, 117.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.5ms
# Speed: 2.6ms preprocess, 109.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.9ms
# Speed: 3.2ms preprocess, 95.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.4ms
# Speed: 3.7ms preprocess, 122.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.2ms
# Speed: 5.7ms preprocess, 108.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.7ms
# Speed: 2.8ms preprocess, 104.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.0ms
# Speed: 3.3ms preprocess, 89.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.5ms
# Speed: 2.3ms preprocess, 100.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.5ms
# Speed: 2.4ms preprocess, 95.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.1ms
# Speed: 2.4ms preprocess, 105.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 109.9ms
# Speed: 2.2ms preprocess, 109.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.9ms
# Speed: 2.8ms preprocess, 98.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.5ms
# Speed: 1.9ms preprocess, 106.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.2ms
# Speed: 2.1ms preprocess, 112.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.6ms
# Speed: 2.2ms preprocess, 100.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.8ms
# Speed: 2.3ms preprocess, 98.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.6ms
# Speed: 3.3ms preprocess, 90.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.3ms
# Speed: 7.5ms preprocess, 110.3ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.3ms
# Speed: 2.4ms preprocess, 106.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.4ms
# Speed: 3.1ms preprocess, 100.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.5ms
# Speed: 7.1ms preprocess, 86.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.7ms
# Speed: 3.4ms preprocess, 110.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.3ms
# Speed: 3.0ms preprocess, 119.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.7ms
# Speed: 2.6ms preprocess, 121.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (10).avi
# Person detection rate: 0.88
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 3/190: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (11).avi
# Video info: 320x240, 483 frames
#
# 0: 480x640 1 person, 117.0ms
# Speed: 2.6ms preprocess, 117.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.8ms
# Speed: 2.3ms preprocess, 109.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.1ms
# Speed: 2.7ms preprocess, 110.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.2ms
# Speed: 2.1ms preprocess, 114.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 107.7ms
# Speed: 4.5ms preprocess, 107.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.5ms
# Speed: 2.4ms preprocess, 109.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 110.2ms
# Speed: 5.0ms preprocess, 110.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.6ms
# Speed: 2.4ms preprocess, 112.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 128.0ms
# Speed: 2.1ms preprocess, 128.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.3ms
# Speed: 2.2ms preprocess, 117.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.0ms
# Speed: 6.0ms preprocess, 119.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.9ms
# Speed: 1.9ms preprocess, 101.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.7ms
# Speed: 2.2ms preprocess, 91.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 116.9ms
# Speed: 2.5ms preprocess, 116.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.1ms
# Speed: 3.4ms preprocess, 104.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.1ms
# Speed: 3.7ms preprocess, 107.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.7ms
# Speed: 6.3ms preprocess, 124.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.8ms
# Speed: 3.6ms preprocess, 120.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 100.1ms
# Speed: 10.3ms preprocess, 100.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.9ms
# Speed: 2.1ms preprocess, 109.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.3ms
# Speed: 4.2ms preprocess, 86.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.3ms
# Speed: 2.1ms preprocess, 100.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 92.4ms
# Speed: 3.3ms preprocess, 92.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.9ms
# Speed: 2.1ms preprocess, 100.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.1ms
# Speed: 4.3ms preprocess, 95.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.0ms
# Speed: 3.8ms preprocess, 104.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 78.0ms
# Speed: 6.9ms preprocess, 78.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.6ms
# Speed: 2.5ms preprocess, 111.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.1ms
# Speed: 5.2ms preprocess, 83.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.2ms
# Speed: 2.9ms preprocess, 100.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.4ms
# Speed: 2.2ms preprocess, 104.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.2ms
# Speed: 2.3ms preprocess, 100.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (11).avi
# Person detection rate: 1.00
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 4/190: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (12).avi
# Video info: 320x240, 182 frames
#
# 0: 480x640 1 person, 114.1ms
# Speed: 2.5ms preprocess, 114.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.6ms
# Speed: 2.3ms preprocess, 125.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.6ms
# Speed: 2.2ms preprocess, 106.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.7ms
# Speed: 2.0ms preprocess, 122.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 140.2ms
# Speed: 2.0ms preprocess, 140.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.9ms
# Speed: 2.1ms preprocess, 109.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.0ms
# Speed: 2.2ms preprocess, 114.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.0ms
# Speed: 3.0ms preprocess, 113.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.4ms
# Speed: 2.3ms preprocess, 118.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.3ms
# Speed: 2.4ms preprocess, 110.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.2ms
# Speed: 2.1ms preprocess, 94.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.6ms
# Speed: 1.9ms preprocess, 82.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 83.4ms
# Speed: 2.3ms preprocess, 83.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 99.7ms
# Speed: 2.2ms preprocess, 99.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.6ms
# Speed: 6.4ms preprocess, 94.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.9ms
# Speed: 3.1ms preprocess, 107.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 100.4ms
# Speed: 4.2ms preprocess, 100.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.6ms
# Speed: 2.9ms preprocess, 100.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 82.6ms
# Speed: 2.5ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.0ms
# Speed: 5.4ms preprocess, 98.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.2ms
# Speed: 5.0ms preprocess, 90.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.0ms
# Speed: 2.3ms preprocess, 108.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 113.0ms
# Speed: 9.0ms preprocess, 113.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.2ms
# Speed: 5.8ms preprocess, 110.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.5ms
# Speed: 5.3ms preprocess, 84.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.1ms
# Speed: 2.2ms preprocess, 104.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 100.6ms
# Speed: 6.5ms preprocess, 100.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.8ms
# Speed: 1.8ms preprocess, 101.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 97.1ms
# Speed: 4.6ms preprocess, 97.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.6ms
# Speed: 1.8ms preprocess, 113.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 110.4ms
# Speed: 3.0ms preprocess, 110.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.6ms
# Speed: 2.4ms preprocess, 104.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (12).avi
# Person detection rate: 0.38
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 5/190: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (13).avi
# Video info: 320x240, 244 frames
#
# 0: 480x640 1 person, 108.3ms
# Speed: 2.3ms preprocess, 108.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.5ms
# Speed: 2.7ms preprocess, 112.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.5ms
# Speed: 1.8ms preprocess, 110.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.0ms
# Speed: 2.1ms preprocess, 107.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.3ms
# Speed: 1.9ms preprocess, 114.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.6ms
# Speed: 2.0ms preprocess, 105.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.7ms
# Speed: 2.5ms preprocess, 108.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 129.1ms
# Speed: 2.7ms preprocess, 129.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 138.6ms
# Speed: 3.5ms preprocess, 138.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.7ms
# Speed: 2.3ms preprocess, 121.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.1ms
# Speed: 2.2ms preprocess, 100.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.6ms
# Speed: 2.8ms preprocess, 91.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.7ms
# Speed: 2.2ms preprocess, 91.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 92.2ms
# Speed: 3.1ms preprocess, 92.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.7ms
# Speed: 2.2ms preprocess, 90.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 116.8ms
# Speed: 2.7ms preprocess, 116.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.5ms
# Speed: 2.5ms preprocess, 84.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 97.9ms
# Speed: 4.3ms preprocess, 97.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 102.1ms
# Speed: 3.2ms preprocess, 102.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 106.2ms
# Speed: 1.8ms preprocess, 106.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.2ms
# Speed: 10.1ms preprocess, 85.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 105.4ms
# Speed: 5.5ms preprocess, 105.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 103.4ms
# Speed: 5.4ms preprocess, 103.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.7ms
# Speed: 2.9ms preprocess, 107.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.6ms
# Speed: 7.7ms preprocess, 89.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.8ms
# Speed: 2.1ms preprocess, 105.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 198.6ms
# Speed: 4.4ms preprocess, 198.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.7ms
# Speed: 4.2ms preprocess, 175.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 116.3ms
# Speed: 2.1ms preprocess, 116.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 116.5ms
# Speed: 2.1ms preprocess, 116.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 109.8ms
# Speed: 7.5ms preprocess, 109.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.8ms
# Speed: 2.3ms preprocess, 118.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (13).avi
# Person detection rate: 0.44
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 6/190: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (14).avi
# Video info: 320x240, 176 frames
#
# 0: 480x640 1 person, 112.7ms
# Speed: 5.1ms preprocess, 112.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.9ms
# Speed: 8.7ms preprocess, 108.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.4ms
# Speed: 8.7ms preprocess, 101.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.8ms
# Speed: 2.4ms preprocess, 114.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.8ms
# Speed: 2.4ms preprocess, 112.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.0ms
# Speed: 2.6ms preprocess, 118.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.4ms
# Speed: 2.7ms preprocess, 111.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.2ms
# Speed: 2.1ms preprocess, 120.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.2ms
# Speed: 1.9ms preprocess, 108.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.6ms
# Speed: 2.6ms preprocess, 103.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.9ms
# Speed: 2.9ms preprocess, 106.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.4ms
# Speed: 3.9ms preprocess, 120.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.0ms
# Speed: 3.9ms preprocess, 121.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.3ms
# Speed: 3.0ms preprocess, 113.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.9ms
# Speed: 2.9ms preprocess, 109.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.9ms
# Speed: 3.7ms preprocess, 114.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.4ms
# Speed: 2.9ms preprocess, 117.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 116.3ms
# Speed: 2.9ms preprocess, 116.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.6ms
# Speed: 3.0ms preprocess, 117.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.6ms
# Speed: 3.0ms preprocess, 120.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.4ms
# Speed: 6.4ms preprocess, 107.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.2ms
# Speed: 3.7ms preprocess, 115.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 102.6ms
# Speed: 8.8ms preprocess, 102.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.7ms
# Speed: 5.3ms preprocess, 113.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.1ms
# Speed: 6.9ms preprocess, 96.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.3ms
# Speed: 2.8ms preprocess, 115.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.8ms
# Speed: 4.7ms preprocess, 107.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 135.9ms
# Speed: 3.1ms preprocess, 135.9ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.8ms
# Speed: 5.8ms preprocess, 103.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 144.4ms
# Speed: 6.7ms preprocess, 144.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.1ms
# Speed: 8.6ms preprocess, 114.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.0ms
# Speed: 3.0ms preprocess, 120.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (14).avi
# Person detection rate: 1.00
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 7/190: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (15).avi
# Video info: 320x240, 140 frames
#
# 0: 480x640 1 person, 121.2ms
# Speed: 4.0ms preprocess, 121.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 134.9ms
# Speed: 3.4ms preprocess, 134.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.3ms
# Speed: 5.0ms preprocess, 121.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 142.3ms
# Speed: 3.2ms preprocess, 142.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 142.5ms
# Speed: 6.0ms preprocess, 142.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 140.0ms
# Speed: 5.7ms preprocess, 140.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.7ms
# Speed: 3.0ms preprocess, 131.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.0ms
# Speed: 3.1ms preprocess, 119.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.8ms
# Speed: 3.1ms preprocess, 123.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.1ms
# Speed: 2.9ms preprocess, 119.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.6ms
# Speed: 2.6ms preprocess, 112.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.2ms
# Speed: 2.5ms preprocess, 123.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 139.0ms
# Speed: 3.1ms preprocess, 139.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 140.0ms
# Speed: 2.4ms preprocess, 140.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.8ms
# Speed: 10.1ms preprocess, 105.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.3ms
# Speed: 3.0ms preprocess, 120.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.8ms
# Speed: 7.2ms preprocess, 115.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 139.4ms
# Speed: 3.4ms preprocess, 139.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.2ms
# Speed: 5.4ms preprocess, 121.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 129.3ms
# Speed: 3.3ms preprocess, 129.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.5ms
# Speed: 7.9ms preprocess, 121.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 153.5ms
# Speed: 3.8ms preprocess, 153.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.9ms
# Speed: 8.5ms preprocess, 115.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 147.4ms
# Speed: 3.1ms preprocess, 147.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.0ms
# Speed: 3.3ms preprocess, 131.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.7ms
# Speed: 3.4ms preprocess, 128.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 133.1ms
# Speed: 3.2ms preprocess, 133.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 151.9ms
# Speed: 3.6ms preprocess, 151.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 173.7ms
# Speed: 3.3ms preprocess, 173.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 146.5ms
# Speed: 3.3ms preprocess, 146.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 149.2ms
# Speed: 2.9ms preprocess, 149.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 136.2ms
# Speed: 2.8ms preprocess, 136.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (15).avi
# Person detection rate: 1.00
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 8/190: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (16).avi
# Video info: 320x240, 177 frames
#
# 0: 480x640 1 person, 141.8ms
# Speed: 2.8ms preprocess, 141.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 144.4ms
# Speed: 2.5ms preprocess, 144.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 147.6ms
# Speed: 3.1ms preprocess, 147.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 145.4ms
# Speed: 3.8ms preprocess, 145.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.1ms
# Speed: 3.2ms preprocess, 122.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.9ms
# Speed: 3.6ms preprocess, 112.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.1ms
# Speed: 2.7ms preprocess, 111.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.3ms
# Speed: 2.6ms preprocess, 114.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.8ms
# Speed: 2.8ms preprocess, 114.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.4ms
# Speed: 3.0ms preprocess, 114.4ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.5ms
# Speed: 3.6ms preprocess, 105.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.7ms
# Speed: 2.8ms preprocess, 120.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.6ms
# Speed: 3.7ms preprocess, 84.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 102.1ms
# Speed: 2.8ms preprocess, 102.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 80.6ms
# Speed: 4.7ms preprocess, 80.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.9ms
# Speed: 2.6ms preprocess, 105.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 97.7ms
# Speed: 5.0ms preprocess, 97.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 99.6ms
# Speed: 2.8ms preprocess, 99.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.7ms
# Speed: 5.8ms preprocess, 88.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.1ms
# Speed: 2.5ms preprocess, 103.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.8ms
# Speed: 5.5ms preprocess, 94.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.9ms
# Speed: 2.7ms preprocess, 111.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.3ms
# Speed: 2.5ms preprocess, 107.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.4ms
# Speed: 2.6ms preprocess, 107.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 101.7ms
# Speed: 5.4ms preprocess, 101.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.5ms
# Speed: 2.6ms preprocess, 107.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 119.9ms
# Speed: 3.2ms preprocess, 119.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 163.1ms
# Speed: 6.6ms preprocess, 163.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 151.2ms
# Speed: 3.3ms preprocess, 151.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 144.8ms
# Speed: 2.4ms preprocess, 144.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 116.4ms
# Speed: 2.4ms preprocess, 116.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.3ms
# Speed: 2.4ms preprocess, 114.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (16).avi
# Person detection rate: 0.62
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 9/190: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (17).avi
# Video info: 320x240, 158 frames
#
# 0: 480x640 2 persons, 122.9ms
# Speed: 2.5ms preprocess, 122.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.1ms
# Speed: 2.6ms preprocess, 120.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 110.1ms
# Speed: 3.9ms preprocess, 110.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.4ms
# Speed: 2.5ms preprocess, 72.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.3ms
# Speed: 2.2ms preprocess, 69.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.6ms
# Speed: 2.3ms preprocess, 70.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.2ms
# Speed: 2.3ms preprocess, 61.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.7ms
# Speed: 2.9ms preprocess, 64.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 97.7ms
# Speed: 2.4ms preprocess, 97.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.6ms
# Speed: 3.4ms preprocess, 87.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.6ms
# Speed: 2.5ms preprocess, 117.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.2ms
# Speed: 2.5ms preprocess, 125.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.8ms
# Speed: 2.5ms preprocess, 111.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.7ms
# Speed: 2.2ms preprocess, 90.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.0ms
# Speed: 4.9ms preprocess, 117.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.7ms
# Speed: 2.5ms preprocess, 111.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.5ms
# Speed: 2.9ms preprocess, 95.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 134.5ms
# Speed: 7.3ms preprocess, 134.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.8ms
# Speed: 2.2ms preprocess, 104.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.2ms
# Speed: 2.4ms preprocess, 86.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.3ms
# Speed: 2.4ms preprocess, 66.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.7ms
# Speed: 2.5ms preprocess, 72.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.6ms
# Speed: 1.8ms preprocess, 58.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.5ms
# Speed: 2.1ms preprocess, 64.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.1ms
# Speed: 2.3ms preprocess, 58.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.5ms
# Speed: 2.1ms preprocess, 57.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.1ms
# Speed: 2.1ms preprocess, 60.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.8ms
# Speed: 2.1ms preprocess, 60.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.7ms
# Speed: 2.5ms preprocess, 60.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.2ms
# Speed: 2.0ms preprocess, 66.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.6ms
# Speed: 2.1ms preprocess, 59.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.6ms
# Speed: 2.0ms preprocess, 62.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (17).avi
# Person detection rate: 0.94
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 10/190: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (18).avi
# Video info: 320x240, 269 frames
#
# 0: 480x640 1 person, 58.9ms
# Speed: 1.9ms preprocess, 58.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.5ms
# Speed: 2.4ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.4ms
# Speed: 2.2ms preprocess, 60.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.1ms
# Speed: 2.5ms preprocess, 63.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 62.3ms
# Speed: 2.3ms preprocess, 62.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.4ms
# Speed: 2.0ms preprocess, 62.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.2ms
# Speed: 2.1ms preprocess, 61.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.7ms
# Speed: 2.3ms preprocess, 55.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.1ms
# Speed: 2.1ms preprocess, 59.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.8ms
# Speed: 1.9ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.3ms
# Speed: 2.3ms preprocess, 64.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.8ms
# Speed: 1.9ms preprocess, 56.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.0ms
# Speed: 2.9ms preprocess, 62.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.7ms
# Speed: 1.9ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.8ms
# Speed: 1.9ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.3ms
# Speed: 1.9ms preprocess, 58.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.9ms
# Speed: 2.7ms preprocess, 70.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.1ms
# Speed: 2.1ms preprocess, 68.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.7ms
# Speed: 2.9ms preprocess, 62.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.3ms
# Speed: 2.1ms preprocess, 55.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.3ms
# Speed: 1.8ms preprocess, 62.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.8ms
# Speed: 2.1ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 71.2ms
# Speed: 2.4ms preprocess, 71.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.1ms
# Speed: 2.0ms preprocess, 55.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.1ms
# Speed: 2.3ms preprocess, 57.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.3ms
# Speed: 2.4ms preprocess, 55.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.4ms
# Speed: 2.0ms preprocess, 55.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.7ms
# Speed: 2.1ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.8ms
# Speed: 1.9ms preprocess, 55.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.1ms
# Speed: 2.5ms preprocess, 61.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (18).avi
# Person detection rate: 1.00
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 11/190: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (19).avi
# Video info: 320x240, 213 frames
#
# 0: 480x640 1 person, 58.8ms
# Speed: 1.7ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.6ms
# Speed: 2.2ms preprocess, 62.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.3ms
# Speed: 2.2ms preprocess, 58.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.7ms
# Speed: 2.0ms preprocess, 60.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.9ms
# Speed: 1.7ms preprocess, 85.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.0ms
# Speed: 2.3ms preprocess, 87.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.7ms
# Speed: 2.2ms preprocess, 104.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.7ms
# Speed: 2.7ms preprocess, 110.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.2ms
# Speed: 2.2ms preprocess, 111.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.5ms
# Speed: 2.4ms preprocess, 96.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.0ms
# Speed: 2.3ms preprocess, 131.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.4ms
# Speed: 2.5ms preprocess, 118.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.4ms
# Speed: 2.5ms preprocess, 73.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.5ms
# Speed: 4.3ms preprocess, 119.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 102.3ms
# Speed: 2.2ms preprocess, 102.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.8ms
# Speed: 2.5ms preprocess, 73.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.9ms
# Speed: 2.2ms preprocess, 75.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.3ms
# Speed: 2.2ms preprocess, 73.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.0ms
# Speed: 2.2ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.7ms
# Speed: 2.3ms preprocess, 74.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.5ms
# Speed: 1.7ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.9ms
# Speed: 2.2ms preprocess, 64.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.5ms
# Speed: 1.8ms preprocess, 59.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.1ms
# Speed: 2.3ms preprocess, 61.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.7ms
# Speed: 2.9ms preprocess, 59.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.6ms
# Speed: 2.4ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.0ms
# Speed: 2.6ms preprocess, 59.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.0ms
# Speed: 2.8ms preprocess, 60.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.4ms
# Speed: 2.2ms preprocess, 60.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.7ms
# Speed: 2.3ms preprocess, 61.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.0ms
# Speed: 2.1ms preprocess, 59.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.4ms
# ...
# Speed: 1.7ms preprocess, 50.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.9ms
# Speed: 2.1ms preprocess, 56.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.6ms
# Speed: 2.2ms preprocess, 53.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.4ms
# Speed: 2.1ms preprocess, 59.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.7ms
# Speed: 2.1ms preprocess, 55.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.1ms
# Speed: 2.6ms preprocess, 66.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (35).avi
# Person detection rate: 1.00
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 30/190: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (36).avi
# Video info: 320x240, 1203 frames
#
# 0: 480x640 2 persons, 57.0ms
# Speed: 2.3ms preprocess, 57.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.2ms
# Speed: 2.1ms preprocess, 58.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.5ms
# Speed: 2.3ms preprocess, 48.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.9ms
# Speed: 2.1ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 49.2ms
# Speed: 2.0ms preprocess, 49.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.3ms
# Speed: 2.0ms preprocess, 55.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.5ms
# Speed: 1.7ms preprocess, 51.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.1ms
# Speed: 2.0ms preprocess, 55.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.3ms
# Speed: 1.8ms preprocess, 48.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.4ms
# Speed: 1.8ms preprocess, 59.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 50.2ms
# Speed: 2.0ms preprocess, 50.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.3ms
# Speed: 2.8ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.1ms
# Speed: 2.3ms preprocess, 56.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.0ms
# Speed: 1.8ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.4ms
# Speed: 1.7ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.9ms
# Speed: 1.5ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.4ms
# Speed: 2.2ms preprocess, 51.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.2ms
# Speed: 2.0ms preprocess, 53.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.7ms
# Speed: 1.9ms preprocess, 50.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.1ms
# Speed: 2.1ms preprocess, 57.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.2ms
# Speed: 1.9ms preprocess, 55.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.3ms
# Speed: 2.1ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.3ms
# Speed: 2.1ms preprocess, 52.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.1ms
# Speed: 1.7ms preprocess, 53.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.7ms
# Speed: 2.0ms preprocess, 48.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.7ms
# Speed: 2.0ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 50.7ms
# Speed: 2.1ms preprocess, 50.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.0ms
# Speed: 2.3ms preprocess, 53.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.8ms
# Speed: 1.8ms preprocess, 50.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.6ms
# Speed: 1.9ms preprocess, 54.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.6ms
# Speed: 1.9ms preprocess, 50.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.7ms
# Speed: 2.1ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (36).avi
# Person detection rate: 1.00
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 31/190: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (37).avi
# Video info: 320x240, 206 frames
#
# 0: 480x640 1 person, 51.3ms
# Speed: 2.1ms preprocess, 51.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.5ms
# Speed: 1.3ms preprocess, 53.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.3ms
# Speed: 2.3ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.8ms
# Speed: 1.8ms preprocess, 53.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.8ms
# Speed: 1.9ms preprocess, 51.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.1ms
# Speed: 2.1ms preprocess, 58.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.4ms
# Speed: 1.6ms preprocess, 56.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.6ms
# Speed: 2.2ms preprocess, 57.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.8ms
# Speed: 2.0ms preprocess, 49.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.7ms
# Speed: 1.7ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.0ms
# Speed: 1.8ms preprocess, 62.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.8ms
# Speed: 2.0ms preprocess, 57.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.6ms
# Speed: 2.2ms preprocess, 55.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.6ms
# Speed: 2.0ms preprocess, 51.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.2ms
# Speed: 1.9ms preprocess, 52.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.6ms
# Speed: 2.2ms preprocess, 50.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.4ms
# Speed: 2.2ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.1ms
# Speed: 1.9ms preprocess, 51.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.1ms
# Speed: 2.0ms preprocess, 56.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.1ms
# Speed: 1.9ms preprocess, 52.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.4ms
# Speed: 2.0ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.3ms
# Speed: 1.6ms preprocess, 60.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.9ms
# Speed: 2.1ms preprocess, 61.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.8ms
# Speed: 2.4ms preprocess, 53.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.2ms
# Speed: 2.2ms preprocess, 85.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.1ms
# Speed: 2.2ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.8ms
# Speed: 1.9ms preprocess, 51.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.3ms
# Speed: 2.0ms preprocess, 50.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.4ms
# Speed: 2.3ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (37).avi
# Person detection rate: 0.81
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 32/190: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (38).avi
# Video info: 320x240, 352 frames
#
# 0: 480x640 1 person, 51.4ms
# Speed: 2.4ms preprocess, 51.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.3ms
# Speed: 1.9ms preprocess, 53.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.6ms
# Speed: 2.0ms preprocess, 49.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.2ms
# Speed: 2.0ms preprocess, 55.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.6ms
# Speed: 1.8ms preprocess, 49.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.5ms
# Speed: 2.5ms preprocess, 55.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.3ms
# Speed: 2.0ms preprocess, 58.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.6ms
# Speed: 2.5ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.7ms
# Speed: 1.9ms preprocess, 48.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.9ms
# Speed: 2.2ms preprocess, 54.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.3ms
# Speed: 2.1ms preprocess, 50.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.9ms
# Speed: 1.9ms preprocess, 74.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 99.8ms
# Speed: 2.5ms preprocess, 99.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.9ms
# Speed: 2.8ms preprocess, 74.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.4ms
# Speed: 2.0ms preprocess, 89.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.5ms
# Speed: 3.4ms preprocess, 90.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.3ms
# Speed: 2.1ms preprocess, 68.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.9ms
# Speed: 2.4ms preprocess, 75.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.6ms
# Speed: 2.1ms preprocess, 53.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.6ms
# Speed: 1.7ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.8ms
# Speed: 2.3ms preprocess, 60.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.0ms
# Speed: 2.4ms preprocess, 64.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.2ms
# Speed: 2.0ms preprocess, 52.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.4ms
# Speed: 1.6ms preprocess, 56.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.0ms
# Speed: 1.9ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.8ms
# Speed: 1.6ms preprocess, 51.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 51.9ms
# Speed: 2.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.1ms
# Speed: 2.0ms preprocess, 51.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 55.9ms
# Speed: 1.9ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.9ms
# Speed: 2.2ms preprocess, 49.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 55.1ms
# Speed: 2.1ms preprocess, 55.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Video: video (38).avi
# Person detection rate: 0.94
# Pose detection rate: 1.00
# Successfully extracted 11 features
#
# Processing video 33/190: ..\data\le2i\Coffee_room_01\Coffee_room_01\Videos\video (39).avi
# Video info: 320x240, 157 frames
#
# 0: 480x640 1 person, 48.4ms
# Speed: 2.1ms preprocess, 48.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.8ms
# Speed: 1.7ms preprocess, 51.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.0ms
# Speed: 2.1ms preprocess, 50.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.2ms
# Speed: 2.4ms preprocess, 49.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.7ms
# Speed: 2.3ms preprocess, 53.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.6ms
# Speed: 2.0ms preprocess, 52.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.5ms
# Speed: 1.9ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 51.3ms
# Speed: 2.6ms preprocess, 51.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.6ms
# Speed: 2.5ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.8ms
# Speed: 2.2ms preprocess, 48.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.7ms
# Speed: 2.0ms preprocess, 52.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.1ms
# Speed: 1.9ms preprocess, 52.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.0ms
# Speed: 2.1ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.3ms
# Speed: 2.0ms preprocess, 55.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.9ms
# Speed: 1.8ms preprocess, 49.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.7ms
