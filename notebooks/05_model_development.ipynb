# %% [markdown]
# ## 5. Model Development
#
# ### `05_model_development.ipynb`

# %%
# Import necessary libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import seaborn as sns
import joblib
# %matplotlib inline

# Set paths
OUTPUT_DIR = "../outputs/models"
FEATURES_CSV = "../outputs/features/video_features.csv"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Load features
if os.path.exists(FEATURES_CSV):
    features_df = pd.read_csv(FEATURES_CSV)
    print(f"Loaded features for {len(features_df)} videos")
    print("Distribution by class:")
    print(features_df['label'].value_counts())
else:
    print(f"Features file not found: {FEATURES_CSV}")
    print("Please run the feature extraction notebook first.")
    # For demonstration, create a sample DataFrame
    features_df = pd.DataFrame({
        'max_velocity': np.random.rand(100),
        'mean_velocity': np.random.rand(100),
        'std_velocity': np.random.rand(100),
        'max_height': np.random.rand(100),
        'min_height': np.random.rand(100),
        'height_range': np.random.rand(100),
        'max_width': np.random.rand(100),
        'min_width': np.random.rand(100),
        'width_range': np.random.rand(100),
        'head_y_change': np.random.rand(100),
        'max_head_y_change': np.random.rand(100),
        'label': np.random.choice(['fall', 'workout'], 100)
    })

# Prepare data for binary classification: workout vs. non-workout
features_df['is_workout'] = features_df['label'] == 'workout'
features_df['is_fall'] = features_df['label'] == 'fall'

# Define feature columns (excluding non-numeric and target columns)
feature_cols = [col for col in features_df.columns 
                if col not in ['label', 'is_workout', 'is_fall', 'video_path']]
feature_cols = [col for col in feature_cols if col in features_df.columns]  # Ensure columns exist

print(f"Using {len(feature_cols)} features: {feature_cols}")

# Handle missing values
features_df[feature_cols] = features_df[feature_cols].fillna(0)

# PART 1: TRAIN WORKOUT DETECTION MODEL
# Split data for workout classifier
X = features_df[feature_cols].values
y_workout = features_df['is_workout'].values

X_train, X_test, y_train, y_test = train_test_split(
    X, y_workout, test_size=0.2, random_state=42, stratify=y_workout)

# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(f"Training data shape: {X_train_scaled.shape}")
print(f"Testing data shape: {X_test_scaled.shape}")

# Create workout detection model
def create_model(input_shape):
    model = Sequential([
        Dense(64, activation='relu', input_dim=input_shape),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.2),
        Dense(16, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# Train workout detection model
workout_model = create_model(X_train_scaled.shape[1])

print("Training workout detection model...")
workout_history = workout_model.fit(
    X_train_scaled, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    callbacks=[
        EarlyStopping(patience=10, restore_best_weights=True),
        ModelCheckpoint(
            os.path.join(OUTPUT_DIR, 'workout_classifier.h5'),
            save_best_only=True
        )
    ],
    verbose=1
)

# Plot training history
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(workout_history.history['accuracy'])
plt.plot(workout_history.history['val_accuracy'])
plt.title('Workout Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(workout_history.history['loss'])
plt.plot(workout_history.history['val_loss'])
plt.title('Workout Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# Evaluate workout model
workout_pred = (workout_model.predict(X_test_scaled) > 0.5).astype(int).flatten()
workout_accuracy = accuracy_score(y_test, workout_pred)
print(f"Workout classification accuracy: {workout_accuracy:.4f}")

# Print classification report
print("\nWorkout Classification Report:")
print(classification_report(y_test, workout_pred))

# Plot confusion matrix
cm = confusion_matrix(y_test, workout_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Non-Workout', 'Workout'],
            yticklabels=['Non-Workout', 'Workout'])
plt.title('Confusion Matrix - Workout Classification')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# PART 2: TRAIN FALL DETECTION MODEL
# In your dataset, it seems all non-workout videos are falls
# Here we're training a separate model specifically for fall detection
X_fall = features_df[feature_cols].values
y_fall = features_df['is_fall'].values

X_train_fall, X_test_fall, y_train_fall, y_test_fall = train_test_split(
    X_fall, y_fall, test_size=0.2, random_state=42, stratify=y_fall)

# Standardize
scaler_fall = StandardScaler()
X_train_fall_scaled = scaler_fall.fit_transform(X_train_fall)
X_test_fall_scaled = scaler_fall.transform(X_test_fall)

# Create and train fall detection model
fall_model = create_model(X_train_fall_scaled.shape[1])  # Reuse same architecture

print("\nTraining fall detection model...")
fall_history = fall_model.fit(
    X_train_fall_scaled, y_train_fall,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    callbacks=[
        EarlyStopping(patience=10, restore_best_weights=True),
        ModelCheckpoint(
            os.path.join(OUTPUT_DIR, 'fall_classifier.h5'),
            save_best_only=True
        )
    ],
    verbose=1
)

# Plot training history
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(fall_history.history['accuracy'])
plt.plot(fall_history.history['val_accuracy'])
plt.title('Fall Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(fall_history.history['loss'])
plt.plot(fall_history.history['val_loss'])
plt.title('Fall Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# Evaluate fall model
fall_pred = (fall_model.predict(X_test_fall_scaled) > 0.5).astype(int).flatten()
fall_accuracy = accuracy_score(y_test_fall, fall_pred)
print(f"Fall classification accuracy: {fall_accuracy:.4f}")

# Print classification report
print("\nFall Classification Report:")
print(classification_report(y_test_fall, fall_pred))

# Plot confusion matrix
cm_fall = confusion_matrix(y_test_fall, fall_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_fall, annot=True, fmt='d', cmap='Reds', 
            xticklabels=['Non-Fall', 'Fall'],
            yticklabels=['Non-Fall', 'Fall'])
plt.title('Confusion Matrix - Fall Classification')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# Save the models and preprocessing objects
joblib.dump(scaler, os.path.join(OUTPUT_DIR, 'workout_scaler.pkl'))
joblib.dump(scaler_fall, os.path.join(OUTPUT_DIR, 'fall_scaler.pkl'))

# Save feature column names
pd.Series(feature_cols).to_csv(os.path.join(OUTPUT_DIR, 'feature_columns.txt'), index=False)

print(f"\nModels and preprocessing objects saved to {OUTPUT_DIR}")

# PART 3: IMPLEMENT THE DETECTION CYCLE
def detect_activity(features, workout_model, fall_model, workout_scaler, fall_scaler):
    """
    Implement the activity detection cycle as specified:
    1. First check if it's a workout activity
    2. If it's a workout, return 'workout'
    3. If it's not a workout, check if it's a fall
    4. Return the appropriate classification
    
    Args:
        features (array): Feature vector
        workout_model: Trained workout detection model
        fall_model: Trained fall detection model
        workout_scaler: StandardScaler for workout model
        fall_scaler: StandardScaler for fall model
        
    Returns:
        str: 'workout', 'fall', or 'normal'
    """
    # Reshape features if needed
    if len(features.shape) == 1:
        features = features.reshape(1, -1)
    
    # Scale features for workout detection
    features_scaled = workout_scaler.transform(features)
    
    # Predict if it's a workout
    is_workout = workout_model.predict(features_scaled) > 0.5
    
    if is_workout[0][0]:
        return 'workout'  # If it's a workout, immediately return without checking fall
    
    # It's not a workout, so check if it's a fall
    features_scaled_fall = fall_scaler.transform(features)
    is_fall = fall_model.predict(features_scaled_fall) > 0.5
    
    if is_fall[0][0]:
        return 'fall'
    else:
        return 'normal'  # Neither workout nor fall

# Test the detection cycle on the test data
print("\nTesting the activity detection cycle...")

# Create a sample to demonstrate each path
test_results = []

# Test some workout samples
workout_samples = X_test[y_test == 1][:5]  # 5 workout samples
for i, sample in enumerate(workout_samples):
    result = detect_activity(sample, workout_model, fall_model, scaler, scaler_fall)
    test_results.append({
        'Sample Type': 'Workout',
        'Model Prediction': result
    })

# Test some fall samples
fall_samples = X_test_fall[y_test_fall == 1][:5]  # 5 fall samples
for i, sample in enumerate(fall_samples):
    result = detect_activity(sample, workout_model, fall_model, scaler, scaler_fall)
    test_results.append({
        'Sample Type': 'Fall',
        'Model Prediction': result
    })

# Display results
results_df = pd.DataFrame(test_results)
print(results_df)

# Create complete video processing pipeline
def process_video(video_path, feature_extract_fn):
    """
    Process a video file through the full detection pipeline:
    1. Extract features using YOLO11
    2. Apply the detection cycle
    
    Args:
        video_path (str): Path to the video file
        feature_extract_fn (function): Function to extract features
        
    Returns:
        str: 'workout', 'fall', or 'normal'
    """
    # Load models and scalers
    model_dir = OUTPUT_DIR
    workout_model = load_model(os.path.join(model_dir, 'workout_classifier.h5'))
    fall_model = load_model(os.path.join(model_dir, 'fall_classifier.h5'))
    workout_scaler = joblib.load(os.path.join(model_dir, 'workout_scaler.pkl'))
    fall_scaler = joblib.load(os.path.join(model_dir, 'fall_scaler.pkl'))
    feature_cols = pd.read_csv(os.path.join(model_dir, 'feature_columns.txt')).values.flatten().tolist()
    
    # Extract features using YOLO11
    keypoints, features = feature_extract_fn(video_path)
    
    if features is None:
        return "Error: Could not extract features from video"
    
    # Create feature vector (must match the training order)
    feature_vector = np.array([features.get(col, 0) for col in feature_cols]).reshape(1, -1)
    
    # Apply detection cycle
    result = detect_activity(feature_vector, workout_model, fall_model, workout_scaler, fall_scaler)
    
    return result

# Example function to execute the complete pipeline (for demonstration)
def demo_pipeline():
    """
    Example integration of YOLO11 feature extraction with detection pipeline
    """
    print("\nExample code for integrating with YOLO11 feature extraction:")
    print("""
    # Import feature extraction function
    from yolo11_feature_extractor import extract_features_from_video
    
    # Process video
    result = process_video("path/to/video.mp4", extract_features_from_video)
    
    # Print result
    print(f"Video contains a {result} activity")
    """)

demo_pipeline()
# Out:
# Loaded features for 490 videos
# Distribution by class:
# label
# workout    300
# fall       190
# Name: count, dtype: int64
# Using 11 features: ['max_velocity', 'mean_velocity', 'std_velocity', 'max_height', 'min_height', 'height_range', 'max_width', 'min_width', 'width_range', 'head_y_change', 'max_head_y_change']
# Training data shape: (392, 11)
# Testing data shape: (98, 11)
# C:\Users\naufa\anaconda3\envs\cv_env\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training workout detection model...
# Epoch 1/50
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4467 - loss: 0.7495
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.4525 - loss: 0.7455 - val_accuracy: 0.7722 - val_loss: 0.6347
# Epoch 2/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6875 - loss: 0.6254
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7547 - loss: 0.6047 - val_accuracy: 0.7975 - val_loss: 0.5677
# Epoch 3/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7500 - loss: 0.5011
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8120 - loss: 0.5366 - val_accuracy: 0.8101 - val_loss: 0.5045
# Epoch 4/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6875 - loss: 0.5480
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8424 - loss: 0.4509 - val_accuracy: 0.8228 - val_loss: 0.4433
# Epoch 5/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7500 - loss: 0.3697
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8273 - loss: 0.3934 - val_accuracy: 0.8354 - val_loss: 0.3987
# Epoch 6/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8750 - loss: 0.2558
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8967 - loss: 0.2983 - val_accuracy: 0.8228 - val_loss: 0.3681
# Epoch 7/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8750 - loss: 0.3223
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8951 - loss: 0.3006 - val_accuracy: 0.8481 - val_loss: 0.3438
# Epoch 8/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7500 - loss: 0.4259
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8772 - loss: 0.3125 - val_accuracy: 0.8734 - val_loss: 0.3325
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9220 - loss: 0.2695
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9211 - loss: 0.2705 - val_accuracy: 0.8734 - val_loss: 0.3249
# Epoch 10/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9375 - loss: 0.3993
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9155 - loss: 0.2796 - val_accuracy: 0.8861 - val_loss: 0.3233
# Epoch 11/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9375 - loss: 0.1766
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8987 - loss: 0.2343 - val_accuracy: 0.8734 - val_loss: 0.3231
# Epoch 12/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8750 - loss: 0.3542
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9083 - loss: 0.2736 - val_accuracy: 0.8734 - val_loss: 0.3220
# Epoch 13/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8750 - loss: 0.2789
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9083 - loss: 0.2430 - val_accuracy: 0.8861 - val_loss: 0.3212
# Epoch 14/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9375 - loss: 0.2372
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9123 - loss: 0.2276 - val_accuracy: 0.8734 - val_loss: 0.3206
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9237 - loss: 0.2206 - val_accuracy: 0.8734 - val_loss: 0.3253
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8954 - loss: 0.2564 - val_accuracy: 0.8734 - val_loss: 0.3335
# Epoch 17/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9324 - loss: 0.1764 - val_accuracy: 0.8734 - val_loss: 0.3350
# Epoch 18/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9001 - loss: 0.2200 - val_accuracy: 0.8608 - val_loss: 0.3374
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9440 - loss: 0.1649 - val_accuracy: 0.8734 - val_loss: 0.3501
# Epoch 20/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9261 - loss: 0.2253 - val_accuracy: 0.8608 - val_loss: 0.3531
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8980 - loss: 0.2332 - val_accuracy: 0.8608 - val_loss: 0.3639
# Epoch 22/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9372 - loss: 0.1957 - val_accuracy: 0.8734 - val_loss: 0.3769
# Epoch 23/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9171 - loss: 0.1973 - val_accuracy: 0.8481 - val_loss: 0.3725
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9415 - loss: 0.1833 - val_accuracy: 0.8354 - val_loss: 0.3776
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Workout classification accuracy: 0.8878
#
# Workout Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.83      0.89      0.86        38
#         True       0.93      0.88      0.91        60
#
#     accuracy                           0.89        98
#    macro avg       0.88      0.89      0.88        98
# weighted avg       0.89      0.89      0.89        98
# Training fall detection model...
# Epoch 1/50
# C:\Users\naufa\anaconda3\envs\cv_env\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.5625 - loss: 0.6569
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5377 - loss: 0.6855 - val_accuracy: 0.7342 - val_loss: 0.5603
# Epoch 2/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8125 - loss: 0.6153
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7743 - loss: 0.5672 - val_accuracy: 0.7468 - val_loss: 0.4572
# Epoch 3/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7500 - loss: 0.5569
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7572 - loss: 0.5135 - val_accuracy: 0.8228 - val_loss: 0.3962
# Epoch 4/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8750 - loss: 0.5061
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7990 - loss: 0.4615 - val_accuracy: 0.8354 - val_loss: 0.3633
# Epoch 5/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6250 - loss: 0.4603
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7887 - loss: 0.4463 - val_accuracy: 0.8481 - val_loss: 0.3205
# Epoch 6/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7500 - loss: 0.4709
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8172 - loss: 0.3831 - val_accuracy: 0.8861 - val_loss: 0.2868
# Epoch 7/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7500 - loss: 0.3581
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8257 - loss: 0.3508 - val_accuracy: 0.8987 - val_loss: 0.2590
# Epoch 8/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6250 - loss: 0.5665
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8173 - loss: 0.3474 - val_accuracy: 0.8987 - val_loss: 0.2302
# Epoch 9/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8750 - loss: 0.3194
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9033 - loss: 0.3090 - val_accuracy: 0.9114 - val_loss: 0.2098
# Epoch 10/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7500 - loss: 0.3030
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8778 - loss: 0.2887 - val_accuracy: 0.9241 - val_loss: 0.1873
# Epoch 11/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.1280
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8997 - loss: 0.2605 - val_accuracy: 0.9241 - val_loss: 0.1820
# Epoch 12/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.1527
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8747 - loss: 0.2950 - val_accuracy: 0.9494 - val_loss: 0.1724
# Epoch 13/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8750 - loss: 0.2977
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8616 - loss: 0.2917 - val_accuracy: 0.9494 - val_loss: 0.1665
# Epoch 14/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9375 - loss: 0.1669
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8996 - loss: 0.2336 - val_accuracy: 0.9494 - val_loss: 0.1529
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9039 - loss: 0.2258 - val_accuracy: 0.9620 - val_loss: 0.1541
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9125 - loss: 0.2169 - val_accuracy: 0.9494 - val_loss: 0.1570
# Epoch 17/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0752
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9158 - loss: 0.2263 - val_accuracy: 0.9620 - val_loss: 0.1526
# Epoch 18/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8125 - loss: 0.3543
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9039 - loss: 0.2449 - val_accuracy: 0.9620 - val_loss: 0.1499
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9077 - loss: 0.2560 - val_accuracy: 0.9367 - val_loss: 0.1568
# Epoch 20/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9375 - loss: 0.1714
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9138 - loss: 0.2311 - val_accuracy: 0.9620 - val_loss: 0.1463
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9103 - loss: 0.2189 - val_accuracy: 0.9494 - val_loss: 0.1465
# Epoch 22/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9375 - loss: 0.1457
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9303 - loss: 0.2255 - val_accuracy: 0.9494 - val_loss: 0.1430
# Epoch 23/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0498
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9383 - loss: 0.1765 - val_accuracy: 0.9494 - val_loss: 0.1420
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8937 - loss: 0.2324 - val_accuracy: 0.9494 - val_loss: 0.1422
# Epoch 25/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8845 - loss: 0.2536 - val_accuracy: 0.9494 - val_loss: 0.1478
# Epoch 26/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9228 - loss: 0.2067 - val_accuracy: 0.9620 - val_loss: 0.1461
# Epoch 27/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9261 - loss: 0.1829 - val_accuracy: 0.9620 - val_loss: 0.1494
# Epoch 28/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8699 - loss: 0.2746 - val_accuracy: 0.9620 - val_loss: 0.1439
# Epoch 29/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9388 - loss: 0.1886 - val_accuracy: 0.9620 - val_loss: 0.1421
# Epoch 30/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9595 - loss: 0.1781 - val_accuracy: 0.9620 - val_loss: 0.1421
# Epoch 31/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8750 - loss: 0.1590
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9071 - loss: 0.1772 - val_accuracy: 0.9620 - val_loss: 0.1390
# Epoch 32/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9316 - loss: 0.1706 - val_accuracy: 0.9620 - val_loss: 0.1452
# Epoch 33/50
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8125 - loss: 0.4158
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9007 - loss: 0.2166 - val_accuracy: 0.9620 - val_loss: 0.1388
# Epoch 34/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9528 - loss: 0.1583 - val_accuracy: 0.9747 - val_loss: 0.1452
# Epoch 35/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9369 - loss: 0.2000 - val_accuracy: 0.9620 - val_loss: 0.1409
# Epoch 36/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9219 - loss: 0.1823 - val_accuracy: 0.9620 - val_loss: 0.1470
# Epoch 37/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9404 - loss: 0.1595 - val_accuracy: 0.9494 - val_loss: 0.1457
# Epoch 38/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9369 - loss: 0.1734 - val_accuracy: 0.9494 - val_loss: 0.1448
# Epoch 39/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9020 - loss: 0.1749 - val_accuracy: 0.9620 - val_loss: 0.1449
# Epoch 40/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9296 - loss: 0.1955 - val_accuracy: 0.9620 - val_loss: 0.1421
# Epoch 41/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8956 - loss: 0.2045 - val_accuracy: 0.9620 - val_loss: 0.1532
# Epoch 42/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9441 - loss: 0.1540 - val_accuracy: 0.9620 - val_loss: 0.1448
# Epoch 43/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9116 - loss: 0.2177 - val_accuracy: 0.9494 - val_loss: 0.1498
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Fall classification accuracy: 0.9082
#
# Fall Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.92      0.93      0.93        60
#         True       0.89      0.87      0.88        38
#
#     accuracy                           0.91        98
#    macro avg       0.90      0.90      0.90        98
# weighted avg       0.91      0.91      0.91        98
# Models and preprocessing objects saved to ../outputs/models
#
# Testing the activity detection cycle...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#   Sample Type Model Prediction
# 0     Workout          workout
# 1     Workout          workout
# 2     Workout           normal
# 3     Workout          workout
# 4     Workout          workout
# 5        Fall          workout
# 6        Fall             fall
# 7        Fall             fall
# 8        Fall             fall
# 9        Fall             fall
#
# Example code for integrating with YOLO11 feature extraction:
#
#     # Import feature extraction function
#     from yolo11_feature_extractor import extract_features_from_video
#
#     # Process video
#     result = process_video("path/to/video.mp4", extract_features_from_video)
#
#     # Print result
#     print(f"Video contains a {result} activity")
